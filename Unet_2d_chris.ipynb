# %% [markdown]
# <a href="https://colab.research.google.com/github/s183796/AIStudentProjects/blob/christine/Unet_2d_chris.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from typing import *
import matplotlib
import matplotlib.pyplot as plt
from IPython.display import Image, display, clear_output
import numpy as np
# %matplotlib nbagg
# %matplotlib inline
import seaborn as sns
import pandas as pd

import torch
import torch.nn as nn
from torchvision import models
from torch.nn.functional import relu
from torch.nn.functional import softmax
import PIL.Image
import os
import torchvision
import cv2

from torchvision import transforms
from sklearn.model_selection import train_test_split

from sklearn.metrics import accuracy_score
from torch.utils.data import DataLoader, Dataset, Subset

import torch.nn.functional as F
import torch.optim as optim
import torchvision.transforms.functional as TF
import glob

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
pip install albumentations
# Out:
# Requirement already satisfied: albumentations in /usr/local/lib/python3.10/dist-packages (1.3.1)
# Requirement already satisfied: numpy>=1.11.1 in /usr/local/lib/python3.10/dist-packages (from albumentations) (1.23.5)
# Requirement already satisfied: scipy>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from albumentations) (1.11.3)
# Requirement already satisfied: scikit-image>=0.16.1 in /usr/local/lib/python3.10/dist-packages (from albumentations) (0.19.3)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.10/dist-packages (from albumentations) (6.0.1)
# Requirement already satisfied: qudida>=0.0.4 in /usr/local/lib/python3.10/dist-packages (from albumentations) (0.0.4)
# Requirement already satisfied: opencv-python-headless>=4.1.1 in /usr/local/lib/python3.10/dist-packages (from albumentations) (4.8.1.78)
# Requirement already satisfied: scikit-learn>=0.19.1 in /usr/local/lib/python3.10/dist-packages (from qudida>=0.0.4->albumentations) (1.2.2)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from qudida>=0.0.4->albumentations) (4.5.0)
# Requirement already satisfied: networkx>=2.2 in /usr/local/lib/python3.10/dist-packages (from scikit-image>=0.16.1->albumentations) (3.2.1)
# Requirement already satisfied: pillow!=7.1.0,!=7.1.1,!=8.3.0,>=6.1.0 in /usr/local/lib/python3.10/dist-packages (from scikit-image>=0.16.1->albumentations) (9.4.0)
# Requirement already satisfied: imageio>=2.4.1 in /usr/local/lib/python3.10/dist-packages (from scikit-image>=0.16.1->albumentations) (2.31.6)
# Requirement already satisfied: tifffile>=2019.7.26 in /usr/local/lib/python3.10/dist-packages (from scikit-image>=0.16.1->albumentations) (2023.9.26)
# Requirement already satisfied: PyWavelets>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-image>=0.16.1->albumentations) (1.4.1)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from scikit-image>=0.16.1->albumentations) (23.2)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.19.1->qudida>=0.0.4->albumentations) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.19.1->qudida>=0.0.4->albumentations) (3.2.0)

# %%
import albumentations as A
from albumentations.pytorch import ToTensorV2

# %%
class UNet(nn.Module): #from https://towardsdatascience.com/cook-your-first-u-net-in-pytorch-b3297a844cf3
    def __init__(self, n_class):
        super().__init__()

        # Encoder
        # In the encoder, convolutional layers with the Conv2d function are used to extract features from the input image.
        # Each block in the encoder consists of two convolutional layers followed by a max-pooling layer, with the exception of the last block which does not include a max-pooling layer.
        # -------
        # input: 1x128x128
        self.e11 = nn.Conv2d(1, 64, kernel_size=3,padding=1)
        self.e12 = nn.Conv2d(64, 64, kernel_size=3,padding=1)
        self.pool1 = nn.MaxPool2d(kernel_size=2, stride=2) #64x64x64

        self.e21 = nn.Conv2d(64, 128, kernel_size=3,padding=1)
        self.e22 = nn.Conv2d(128, 128, kernel_size=3,padding=1)
        self.pool2 = nn.MaxPool2d(kernel_size=2, stride=2) #32x32x128

        self.e31 = nn.Conv2d(128, 256, kernel_size=3,padding=1)
        self.e32 = nn.Conv2d(256, 256, kernel_size=3,padding=1)

        self.pool3 = nn.MaxPool2d(kernel_size=2, stride=2) #16x16x256

        self.e41 = nn.Conv2d(256, 512, kernel_size=3,padding=1)
        self.e42 = nn.Conv2d(512, 512, kernel_size=3,padding=1)
        self.pool4 = nn.MaxPool2d(kernel_size=2, stride=2) #8x8x512

        self.e51 = nn.Conv2d(512, 1024, kernel_size=3,padding=1)
        self.e52 = nn.Conv2d(1024, 1024, kernel_size=3,padding=1)

        self.upconv1 = nn.ConvTranspose2d(1024,512,kernel_size=2,stride=2) #16x16x1024
        self.d11 = nn.Conv2d(1024,512,kernel_size=3,padding=1)
        self.d12 = nn.Conv2d(512,512,kernel_size=3,padding=1)

        self.upconv2 = nn.ConvTranspose2d(512,256,kernel_size=2,stride=2) #
        self.d21 = nn.Conv2d(512,256,kernel_size=3,padding=1)
        self.d22 = nn.Conv2d(256,256,kernel_size=3,padding=1)

        self.upconv3 = nn.ConvTranspose2d(256,128,kernel_size=2,stride=2)
        self.d31 = nn.Conv2d(256,128,kernel_size=3,padding=1)
        self.d32 = nn.Conv2d(128,128,kernel_size=3,padding=1)

        self.upconv4 = nn.ConvTranspose2d(128,64,kernel_size=2,stride=2)
        self.d41 = nn.Conv2d(128,64,kernel_size=3,padding=1)
        self.d42 = nn.Conv2d(64,64,kernel_size=3,padding=1)

        self.outconv = nn.Conv2d(64, n_class, kernel_size=1)

    def forward(self, x):
        # Encoder
        xe11 = F.relu(self.e11(x))
        xe12 = F.relu(self.e12(xe11))
        xp1 = self.pool1(xe12)

        xe21 = F.relu(self.e21(xp1))
        xe22 = F.relu(self.e22(xe21))
        xp2 = self.pool2(xe22)


        xe31 = F.relu(self.e31(xp2))
        xe32 = F.relu(self.e32(xe31))


        xp3 = self.pool3(xe32)

        xe41 = F.relu(self.e41(xp3))
        xe42 = F.relu(self.e42(xe41))
        xp4 = self.pool4(xe42)

        xe51 = F.relu(self.e51(xp4))
        xe52 = F.relu(self.e52(xe51))

        # Up-convolutions
        xup1 = self.upconv1(xe52)
        #xcat=xup1
        xcat = torch.cat([xup1, xe42], dim=1)

        xup21 = F.relu(self.d11(xcat))
        xup22 = F.relu(self.d12(xup21))

        xup2 = self.upconv2(xup22)
        #xcat2=xup2
        #xcat2 = torch.cat([xup2, xe32[:,:,:-1,:-1]], dim=1)
        xcat2 = torch.cat([xup2, xe32], dim=1)


        xup31 = F.relu(self.d21(xcat2))
        xup32 = F.relu(self.d22(xup31))
        xup3 = self.upconv3(xup32)
        #xcat3=xup3
        xcat3 = torch.cat([xup3, xe22], dim=1)

        xup41 = F.relu(self.d31(xcat3))
        xup42 = F.relu(self.d32(xup41))

        xup4 = self.upconv4(xup42)
        #xcat4 = torch.cat([xup4, xe12[:,:,2:-3,2:-3]], dim=1)
        xcat4 = torch.cat([xup4, xe12], dim=1)
        #xcat4=xup4
        xup51 = F.relu(self.d41(xcat4))
        xup52 = F.relu(self.d42(xup51))

        out = self.outconv(xup52)

        output = softmax(out,dim=1)

        return output

# %%
#Setting up hyper parameters, from exercise week 6


loss_fn =  nn.CrossEntropyLoss()         # <-- Your code here.

import random

# %%
class SOCDataset(Dataset):
    def __init__(self, root_dir, transform=None,transform_flip=None):
        self.root_dir = root_dir
        self.image_folder = os.path.join(root_dir, 'data/')
        self.label_folder = os.path.join(root_dir, 'labels/')
        self.transform = transform
        self.transform_flip = transform_flip

        self.image_filenames = sorted([f for f in os.listdir(self.image_folder) if f.endswith('.tiff')][:400])
        self.label_filenames = sorted([f for f in os.listdir(self.label_folder) if f.endswith('.tif')][:400])

    def __len__(self):
        return len(self.image_filenames)

    def __getitem__(self, idx):
      img_name = os.path.join(self.image_folder, self.image_filenames[idx])

      number1=img_name[-8:-5]
      label_name=os.path.join(self.label_folder,'slice__'+str(number1)+'.tif')

      image = cv2.imread(img_name, cv2.IMREAD_GRAYSCALE)
      label = cv2.imread(label_name, cv2.IMREAD_GRAYSCALE)

      image=np.array(image)
      label=np.array(label)

      if self.transform is not None:
        augmentations=self.transform(image=image,mask=label)

      image=augmentations["image"]
      label=augmentations["mask"]

      return image, label

# %%
class SOCDataset_label(Dataset):
    def __init__(self, root_dir, transform=None,transform_flip=None):
        self.root_dir = root_dir
        self.image_folder = os.path.join(root_dir, 'data/')
        self.label_folder = os.path.join(root_dir, 'labels/')
        self.transform = transform
        self.transform_flip = transform_flip

        self.image_filenames = sorted([f for f in os.listdir(self.image_folder) if f.endswith('.tiff')][-100:])
        self.label_filenames = sorted([f for f in os.listdir(self.label_folder) if f.endswith('.tif')][-100:])


    def __len__(self):
        return len(self.image_filenames)

    def __getitem__(self, idx):
      img_name = os.path.join(self.image_folder, self.image_filenames[idx])

      number1=img_name[-8:-5]
      label_name=os.path.join(self.label_folder,'slice__'+str(number1)+'.tif')

      image = cv2.imread(img_name, cv2.IMREAD_GRAYSCALE)
      label = cv2.imread(label_name, cv2.IMREAD_GRAYSCALE)

      image=np.array(image)
      label=np.array(label)

      if self.transform is not None:
        augmentations=self.transform(image=image,mask=label)

      image=augmentations["image"]
      label=augmentations["mask"]

      return image, label

# %%
transform = A.Compose(
    [
     A.HorizontalFlip(p=0.5),
     A.RandomCrop(width=128, height=128),
     A.VerticalFlip(p=0.1),
     A.RandomBrightnessContrast(p=0.2),  # Adjust brightness/contrast
     A.GaussNoise(p=0.2),  # Add Gaussian noise
     A.Resize(64, 64, p=0.2),  # Downsample to 64x64
     A.Resize(128, 128),  # Upsample back to 128x128
     A.Normalize(
        mean=[0.5],
        std=[0.5],
        max_pixel_value=255.0,
     ),
     ToTensorV2(),
    ]
)

transform_test = A.Compose(
    [
     #A.HorizontalFlip(p=0.5),
     #A.RandomCrop(width=128, height=128),
     #A.VerticalFlip(p=0.1),
     #A.RandomBrightnessContrast(p=0.2),  # Adjust brightness/contrast
     #A.GaussNoise(p=0.2),  # Add Gaussian noise
     #A.Resize(64, 64, p=0.2),  # Downsample to 64x64
     #A.Resize(128, 128),  # Upsample back to 128x128
     A.Normalize(
        mean=[0.5],
        std=[0.5],
        max_pixel_value=255.0,
     ),
     ToTensorV2(),
    ]
)

# %%
SOC_dataset = SOCDataset(root_dir='drive/My Drive//AI data/', transform = transform)

# %%
SOC_dataset_label=SOCDataset_label(root_dir='drive/My Drive//AI data/', transform = transform_test)

# %%
image,label=SOC_dataset[33]

plt.figure(dpi=200)
plt.imshow(image[0,:,:])

plt.figure(dpi=200)
plt.imshow(label)

# %%
pip install torchmetrics
# Out:
# Collecting torchmetrics
#   Downloading torchmetrics-1.2.0-py3-none-any.whl (805 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 805.2/805.2 kB 14.1 MB/s eta 0:00:00
# Requirement already satisfied: numpy>1.20.0 in /usr/local/lib/python3.10/dist-packages (from torchmetrics) (1.23.5)
# Requirement already satisfied: torch>=1.8.1 in /usr/local/lib/python3.10/dist-packages (from torchmetrics) (2.1.0+cu118)
# Collecting lightning-utilities>=0.8.0 (from torchmetrics)
#   Downloading lightning_utilities-0.10.0-py3-none-any.whl (24 kB)
# Requirement already satisfied: packaging>=17.1 in /usr/local/lib/python3.10/dist-packages (from lightning-utilities>=0.8.0->torchmetrics) (23.2)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from lightning-utilities>=0.8.0->torchmetrics) (67.7.2)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from lightning-utilities>=0.8.0->torchmetrics) (4.5.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.1->torchmetrics) (3.13.1)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.1->torchmetrics) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.1->torchmetrics) (3.2.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.1->torchmetrics) (3.1.2)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.1->torchmetrics) (2023.6.0)
# Requirement already satisfied: triton==2.1.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.1->torchmetrics) (2.1.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.8.1->torchmetrics) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.8.1->torchmetrics) (1.3.0)
# Installing collected packages: lightning-utilities, torchmetrics
# Successfully installed lightning-utilities-0.10.0 torchmetrics-1.2.0

# %%
from torchmetrics.classification import JaccardIndex

# %%
from sklearn.model_selection import train_test_split

TEST_SIZE = 0.3
BATCH_SIZE = 16
SEED = 42

# generate indices: instead of the actual data we pass in integers instead
train_indices, test_indices = train_test_split(
    range(len(SOC_dataset)),
    test_size=TEST_SIZE,
    random_state=SEED
)

val_indices, test_indices = train_test_split(
    test_indices,
    test_size=0.5,
    random_state=SEED
)

# generate subset based on indices
train_split = Subset(SOC_dataset, train_indices)
test_split = Subset(SOC_dataset, test_indices)
val_split = Subset(SOC_dataset_label, val_indices)

# create batches
train_loader = DataLoader(train_split, batch_size=BATCH_SIZE, shuffle=True)
test_loader = DataLoader(test_split, batch_size=BATCH_SIZE)
val_loader = DataLoader(val_split, batch_size=BATCH_SIZE)

# %%
net=UNet(n_class=3)

from torchmetrics.functional.classification import dice
from torchmetrics.classification import MulticlassAccuracy
#metric=Dice(num_classes=3)


optimizer = optim.Adam(net.parameters(), lr=0.0001)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
net.to(device)

jaccard=JaccardIndex(task="multiclass", num_classes=3).to(device)
accuracy=MulticlassAccuracy(num_classes=3).to(device)
batch_size = 16
num_epochs = 200 #changing the num_epochs from 2 to 12
validation_every_steps = np.ceil(len(train_loader.dataset)/batch_size)

step = 0
net.train()

train_accuracies_jaccard = []
train_accuracies_dice = []
train_accuracies_pixel = []
valid_accuracies_jaccard = []
valid_accuracies_dice = []
valid_accuracies_pixel = []

for epoch in range(num_epochs):
    train_accuracies_batches_jaccard = []
    train_accuracies_batches_dice = []
    train_accuracies_batches_pixel = []

    for inputs, targets in train_loader:
        inputs, targets = inputs.to(device), targets.to(device)


        # Forward pass, compute gradients, perform one training step.
        # Your code here!
        # Forward pass.
        output = net(inputs)

        un_target=targets.unique()
        # Compute loss.
        targets[targets==un_target[0]]=0
        targets[targets==un_target[1]]=1
        targets[targets==un_target[2]]=2

        targets = targets.to(torch.int64)

        loss = loss_fn(output, targets)

        # Clean up gradients from the model.
        optimizer.zero_grad()

        # Compute gradients based on the loss from the current batch (backpropagation).
        loss.backward()

        # Take one optimizer step using the gradients computed in the previous step.
        optimizer.step()

        # Increment step counter
        step += 1

        # Compute accuracy.
        predictions = torch.argmax(output,dim=1)
        train_accuracies_batches_dice.append(dice(predictions,targets).cpu())
        train_accuracies_batches_jaccard.append(jaccard(predictions,targets).cpu())
        train_accuracies_batches_pixel.append(accuracy(predictions,targets).cpu())

        if step % validation_every_steps == 0:

            # Append average training accuracy to list.
            train_accuracies_jaccard.append(np.mean(train_accuracies_batches_jaccard))
            train_accuracies_dice.append(np.mean(train_accuracies_batches_dice))
            train_accuracies_pixel.append(np.mean(train_accuracies_batches_pixel))

            train_accuracies_batches_jaccard = []
            train_accuracies_batches_dice = []
            train_accuracies_batches_pixel = []

            # Compute accuracies on validation set.
            valid_accuracies_batches_jaccard = []
            valid_accuracies_batches_dice = []
            valid_accuracies_batches_pixel = []
            with torch.no_grad():
                net.eval()
                for inputs, targets in test_loader:
                    inputs, targets = inputs.to(device), targets.to(device)
                    output = net(inputs)

                    un_target=targets.unique()
                    # Compute loss.
                    targets[targets==un_target[0]]=0
                    targets[targets==un_target[1]]=1
                    targets[targets==un_target[2]]=2

                    targets = targets.to(torch.int64)

                    loss = loss_fn(output, targets)

                    predictions = output.max(1)[1]
                    # Multiply by len(x) because the final batch of DataLoader may be smaller (drop_last=False).
                    valid_accuracies_batches_dice.append(dice(predictions,targets).cpu())
                    valid_accuracies_batches_jaccard.append(jaccard(predictions,targets).cpu())
                    valid_accuracies_batches_pixel.append(accuracy(predictions,targets).cpu())

                net.train()

            # Append average validation accuracy to list.
            valid_accuracies_jaccard.append(np.sum(valid_accuracies_batches_jaccard) / len(test_loader))
            valid_accuracies_dice.append(np.sum(valid_accuracies_batches_dice) / len(test_loader))
            valid_accuracies_pixel.append(np.sum(valid_accuracies_batches_pixel) / len(test_loader))

            print(f"Step {step:<5}   training accuracy with jaccard: {train_accuracies_jaccard[-1]}")
            print(f"             training accuracy with dice: {train_accuracies_dice[-1]}")
            print(f"             training accuracy with pixel by pixel: {train_accuracies_pixel[-1]}")
            print(f"             test accuracy with jaccard: {valid_accuracies_jaccard[-1]}")
            print(f"             test accuracy with dice: {valid_accuracies_dice[-1]}")
            print(f"             test accuracy with pixel by pixel: {valid_accuracies_pixel[-1]}")


print("Finished training.")
# Out:
# Step 18      training accuracy with jaccard: 0.2748560905456543
#              training accuracy with dice: 0.42324426770210266
#              training accuracy with pixel by pixel: 0.4952198565006256
#              test accuracy with jaccard: 0.45072656869888306
#              test accuracy with dice: 0.5698582530021667
#              test accuracy with pixel by pixel: 0.6597279906272888
# Step 36      training accuracy with jaccard: 0.4773411154747009
#              training accuracy with dice: 0.6000556945800781
#              training accuracy with pixel by pixel: 0.6763291954994202
#              test accuracy with jaccard: 0.47333529591560364
#              test accuracy with dice: 0.6724507212638855
#              test accuracy with pixel by pixel: 0.6115729212760925
# Step 54      training accuracy with jaccard: 0.7238026261329651
#              training accuracy with dice: 0.8315715789794922
#              training accuracy with pixel by pixel: 0.8207663893699646
#              test accuracy with jaccard: 0.8481011390686035
#              test accuracy with dice: 0.9152358174324036
#              test accuracy with pixel by pixel: 0.9163497686386108
# Step 72      training accuracy with jaccard: 0.8548267483711243
#              training accuracy with dice: 0.9205105900764465
#              training accuracy with pixel by pixel: 0.9173688888549805
#              test accuracy with jaccard: 0.8654073476791382
#              test accuracy with dice: 0.9260880351066589
#              test accuracy with pixel by pixel: 0.9251406788825989
# Step 90      training accuracy with jaccard: 0.8792738914489746
#              training accuracy with dice: 0.9341714382171631
#              training accuracy with pixel by pixel: 0.9316680431365967
#              test accuracy with jaccard: 0.8904723525047302
#              test accuracy with dice: 0.9415881037712097
#              test accuracy with pixel by pixel: 0.9383748769760132
# Step 108     training accuracy with jaccard: 0.889394998550415
#              training accuracy with dice: 0.9408931732177734
#              training accuracy with pixel by pixel: 0.9369557499885559
#              test accuracy with jaccard: 0.8901848793029785
#              test accuracy with dice: 0.9405362010002136
#              test accuracy with pixel by pixel: 0.9372182488441467
# Step 126     training accuracy with jaccard: 0.900177538394928
#              training accuracy with dice: 0.9464619755744934
#              training accuracy with pixel by pixel: 0.94367915391922
#              test accuracy with jaccard: 0.904085099697113
#              test accuracy with dice: 0.9489815831184387
#              test accuracy with pixel by pixel: 0.9471065402030945
# Step 144     training accuracy with jaccard: 0.9033944606781006
#              training accuracy with dice: 0.9489514827728271
#              training accuracy with pixel by pixel: 0.9452399015426636
#              test accuracy with jaccard: 0.9076491594314575
#              test accuracy with dice: 0.9500605463981628
#              test accuracy with pixel by pixel: 0.9456490278244019
# Step 162     training accuracy with jaccard: 0.9106684923171997
#              training accuracy with dice: 0.9527223110198975
#              training accuracy with pixel by pixel: 0.9492447376251221
#              test accuracy with jaccard: 0.9168667793273926
#              test accuracy with dice: 0.9550526738166809
#              test accuracy with pixel by pixel: 0.9533629417419434
# Step 180     training accuracy with jaccard: 0.917883574962616
#              training accuracy with dice: 0.9558423161506653
#              training accuracy with pixel by pixel: 0.9543552398681641
#              test accuracy with jaccard: 0.9211785197257996
#              test accuracy with dice: 0.9586432576179504
#              test accuracy with pixel by pixel: 0.9564838409423828
# Step 198     training accuracy with jaccard: 0.9213330149650574
#              training accuracy with dice: 0.9581360220909119
#              training accuracy with pixel by pixel: 0.9560628533363342
#              test accuracy with jaccard: 0.9240012764930725
#              test accuracy with dice: 0.960505485534668
#              test accuracy with pixel by pixel: 0.9563405513763428
# Step 216     training accuracy with jaccard: 0.9266970753669739
#              training accuracy with dice: 0.9610905051231384
#              training accuracy with pixel by pixel: 0.9588283896446228
#              test accuracy with jaccard: 0.9322909116744995
#              test accuracy with dice: 0.9639313817024231
#              test accuracy with pixel by pixel: 0.9616827964782715
# Step 234     training accuracy with jaccard: 0.9281050562858582
#              training accuracy with dice: 0.9620037078857422
#              training accuracy with pixel by pixel: 0.9597437977790833
#              test accuracy with jaccard: 0.9191702008247375
#              test accuracy with dice: 0.9569683074951172
#              test accuracy with pixel by pixel: 0.9523142576217651
# Step 252     training accuracy with jaccard: 0.9269496202468872
#              training accuracy with dice: 0.9612312316894531
#              training accuracy with pixel by pixel: 0.9595655798912048
#              test accuracy with jaccard: 0.9368085265159607
#              test accuracy with dice: 0.966724693775177
#              test accuracy with pixel by pixel: 0.9647500514984131
# Step 270     training accuracy with jaccard: 0.9349238276481628
#              training accuracy with dice: 0.9656988978385925
#              training accuracy with pixel by pixel: 0.9643220901489258
#              test accuracy with jaccard: 0.9390213489532471
#              test accuracy with dice: 0.9679816365242004
#              test accuracy with pixel by pixel: 0.9663160443305969
# Step 288     training accuracy with jaccard: 0.9419195652008057
#              training accuracy with dice: 0.9694440364837646
#              training accuracy with pixel by pixel: 0.9684577584266663
#              test accuracy with jaccard: 0.9459262490272522
#              test accuracy with dice: 0.9717127680778503
#              test accuracy with pixel by pixel: 0.9700158834457397
# Step 306     training accuracy with jaccard: 0.9470990300178528
#              training accuracy with dice: 0.9721946716308594
#              training accuracy with pixel by pixel: 0.9718608856201172
#              test accuracy with jaccard: 0.9516270160675049
#              test accuracy with dice: 0.9746081233024597
#              test accuracy with pixel by pixel: 0.9734420776367188
# Step 324     training accuracy with jaccard: 0.9519252777099609
#              training accuracy with dice: 0.9749249219894409
#              training accuracy with pixel by pixel: 0.9744927287101746
#              test accuracy with jaccard: 0.9528837203979492
#              test accuracy with dice: 0.9757483601570129
#              test accuracy with pixel by pixel: 0.9760187864303589
# Step 342     training accuracy with jaccard: 0.9544835686683655
#              training accuracy with dice: 0.9764747619628906
#              training accuracy with pixel by pixel: 0.9758224487304688
#              test accuracy with jaccard: 0.9574664831161499
#              test accuracy with dice: 0.9778982996940613
#              test accuracy with pixel by pixel: 0.9785177111625671
# Step 360     training accuracy with jaccard: 0.9578924179077148
#              training accuracy with dice: 0.9783562421798706
#              training accuracy with pixel by pixel: 0.9781669974327087
#              test accuracy with jaccard: 0.9463517665863037
#              test accuracy with dice: 0.9723221659660339
#              test accuracy with pixel by pixel: 0.9703570604324341
# Step 378     training accuracy with jaccard: 0.9565131068229675
#              training accuracy with dice: 0.9775062203407288
#              training accuracy with pixel by pixel: 0.9776169657707214
#              test accuracy with jaccard: 0.9576514959335327
#              test accuracy with dice: 0.9780213236808777
#              test accuracy with pixel by pixel: 0.9782885909080505
# Step 396     training accuracy with jaccard: 0.9617533087730408
#              training accuracy with dice: 0.9804407954216003
#              training accuracy with pixel by pixel: 0.9802523851394653
#              test accuracy with jaccard: 0.9629925489425659
#              test accuracy with dice: 0.9811296463012695
#              test accuracy with pixel by pixel: 0.98055499792099
# Step 414     training accuracy with jaccard: 0.9634115695953369
#              training accuracy with dice: 0.981191873550415
#              training accuracy with pixel by pixel: 0.9811274409294128
#              test accuracy with jaccard: 0.9638528823852539
#              test accuracy with dice: 0.9815216064453125
#              test accuracy with pixel by pixel: 0.981492817401886
# Step 432     training accuracy with jaccard: 0.9659719467163086
#              training accuracy with dice: 0.9825074672698975
#              training accuracy with pixel by pixel: 0.9824383854866028
#              test accuracy with jaccard: 0.9634126424789429
#              test accuracy with dice: 0.9812281727790833
#              test accuracy with pixel by pixel: 0.9810322523117065
# Step 450     training accuracy with jaccard: 0.9668030142784119
#              training accuracy with dice: 0.98301762342453
#              training accuracy with pixel by pixel: 0.9827731251716614
#              test accuracy with jaccard: 0.963693380355835
#              test accuracy with dice: 0.9812593460083008
#              test accuracy with pixel by pixel: 0.9806397557258606
# Step 468     training accuracy with jaccard: 0.9669409990310669
#              training accuracy with dice: 0.9831013083457947
#              training accuracy with pixel by pixel: 0.9828389286994934
#              test accuracy with jaccard: 0.9660965204238892
#              test accuracy with dice: 0.9827362895011902
#              test accuracy with pixel by pixel: 0.9822142124176025
# Step 486     training accuracy with jaccard: 0.9667279124259949
#              training accuracy with dice: 0.9830245971679688
#              training accuracy with pixel by pixel: 0.9827958345413208
#              test accuracy with jaccard: 0.9678726196289062
#              test accuracy with dice: 0.983501136302948
#              test accuracy with pixel by pixel: 0.9837278127670288
# Step 504     training accuracy with jaccard: 0.9670844674110413
#              training accuracy with dice: 0.9831157326698303
#              training accuracy with pixel by pixel: 0.9829804301261902
#              test accuracy with jaccard: 0.9678348302841187
#              test accuracy with dice: 0.9834744334220886
#              test accuracy with pixel by pixel: 0.98394775390625
# Step 522     training accuracy with jaccard: 0.9681945443153381
#              training accuracy with dice: 0.9837841391563416
#              training accuracy with pixel by pixel: 0.9836105704307556
#              test accuracy with jaccard: 0.9684014320373535
#              test accuracy with dice: 0.9838218688964844
#              test accuracy with pixel by pixel: 0.9845851063728333
# Step 540     training accuracy with jaccard: 0.96940678358078
#              training accuracy with dice: 0.9844472408294678
#              training accuracy with pixel by pixel: 0.9842579364776611
#              test accuracy with jaccard: 0.9654650092124939
#              test accuracy with dice: 0.9825207591056824
#              test accuracy with pixel by pixel: 0.9813463687896729
# Step 558     training accuracy with jaccard: 0.9688961505889893
#              training accuracy with dice: 0.9841980338096619
#              training accuracy with pixel by pixel: 0.9840190410614014
#              test accuracy with jaccard: 0.9691355228424072
#              test accuracy with dice: 0.9842309951782227
#              test accuracy with pixel by pixel: 0.984495997428894
# Step 576     training accuracy with jaccard: 0.9702802300453186
#              training accuracy with dice: 0.9849255681037903
#              training accuracy with pixel by pixel: 0.98476243019104
#              test accuracy with jaccard: 0.9687341451644897
#              test accuracy with dice: 0.9839169383049011
#              test accuracy with pixel by pixel: 0.9833383560180664
# Step 594     training accuracy with jaccard: 0.9711833596229553
#              training accuracy with dice: 0.9855289459228516
#              training accuracy with pixel by pixel: 0.9852170944213867
#              test accuracy with jaccard: 0.9698372483253479
#              test accuracy with dice: 0.9848238825798035
#              test accuracy with pixel by pixel: 0.9849191904067993
# Step 612     training accuracy with jaccard: 0.9713516235351562
#              training accuracy with dice: 0.985428512096405
#              training accuracy with pixel by pixel: 0.985238790512085
#              test accuracy with jaccard: 0.9696595668792725
#              test accuracy with dice: 0.9844935536384583
#              test accuracy with pixel by pixel: 0.9846405982971191
# Step 630     training accuracy with jaccard: 0.9692501425743103
#              training accuracy with dice: 0.9843514561653137
#              training accuracy with pixel by pixel: 0.9841737747192383
#              test accuracy with jaccard: 0.9710749387741089
#              test accuracy with dice: 0.9852027893066406
#              test accuracy with pixel by pixel: 0.9849421381950378
# Step 648     training accuracy with jaccard: 0.9709975719451904
#              training accuracy with dice: 0.9851906895637512
#              training accuracy with pixel by pixel: 0.9852071404457092
#              test accuracy with jaccard: 0.9707529544830322
#              test accuracy with dice: 0.9851767420768738
#              test accuracy with pixel by pixel: 0.9853827953338623
# Step 666     training accuracy with jaccard: 0.972205400466919
#              training accuracy with dice: 0.9857919216156006
#              training accuracy with pixel by pixel: 0.9858781099319458
#              test accuracy with jaccard: 0.9704698324203491
#              test accuracy with dice: 0.9847777485847473
#              test accuracy with pixel by pixel: 0.9846528768539429
# Step 684     training accuracy with jaccard: 0.9720783233642578
#              training accuracy with dice: 0.9857822060585022
#              training accuracy with pixel by pixel: 0.9855210185050964
#              test accuracy with jaccard: 0.9720258712768555
#              test accuracy with dice: 0.9857568740844727
#              test accuracy with pixel by pixel: 0.9859967827796936
# Step 702     training accuracy with jaccard: 0.9726945161819458
#              training accuracy with dice: 0.9861100316047668
#              training accuracy with pixel by pixel: 0.9860332012176514
#              test accuracy with jaccard: 0.9728915691375732
#              test accuracy with dice: 0.986103355884552
#              test accuracy with pixel by pixel: 0.9856281280517578
# Step 720     training accuracy with jaccard: 0.9733279347419739
#              training accuracy with dice: 0.9864646196365356
#              training accuracy with pixel by pixel: 0.986297070980072
#              test accuracy with jaccard: 0.9715083837509155
#              test accuracy with dice: 0.9854898452758789
#              test accuracy with pixel by pixel: 0.9847618341445923
# Step 738     training accuracy with jaccard: 0.9717534184455872
#              training accuracy with dice: 0.9856745600700378
#              training accuracy with pixel by pixel: 0.9854400157928467
#              test accuracy with jaccard: 0.9727699756622314
#              test accuracy with dice: 0.9860327839851379
#              test accuracy with pixel by pixel: 0.9856330156326294
# Step 756     training accuracy with jaccard: 0.9722115397453308
#              training accuracy with dice: 0.985849142074585
#              training accuracy with pixel by pixel: 0.9857411980628967
#              test accuracy with jaccard: 0.9728636741638184
#              test accuracy with dice: 0.9861796498298645
#              test accuracy with pixel by pixel: 0.9862072467803955
# Step 774     training accuracy with jaccard: 0.9728731513023376
#              training accuracy with dice: 0.9862518310546875
#              training accuracy with pixel by pixel: 0.9861088991165161
#              test accuracy with jaccard: 0.9735798239707947
#              test accuracy with dice: 0.9867696762084961
#              test accuracy with pixel by pixel: 0.9863195419311523
# Step 792     training accuracy with jaccard: 0.9728405475616455
#              training accuracy with dice: 0.9861352443695068
#              training accuracy with pixel by pixel: 0.9861884713172913
#              test accuracy with jaccard: 0.9740465879440308
#              test accuracy with dice: 0.9867445826530457
#              test accuracy with pixel by pixel: 0.9864598512649536
# Step 810     training accuracy with jaccard: 0.9743472337722778
#              training accuracy with dice: 0.9869028925895691
#              training accuracy with pixel by pixel: 0.9869041442871094
#              test accuracy with jaccard: 0.9763018488883972
#              test accuracy with dice: 0.9878533482551575
#              test accuracy with pixel by pixel: 0.9876753091812134
# Step 828     training accuracy with jaccard: 0.9745700359344482
#              training accuracy with dice: 0.9870554804801941
#              training accuracy with pixel by pixel: 0.9869410395622253
#              test accuracy with jaccard: 0.9726739525794983
#              test accuracy with dice: 0.9860522150993347
#              test accuracy with pixel by pixel: 0.985714316368103
# Step 846     training accuracy with jaccard: 0.9749641418457031
#              training accuracy with dice: 0.9873284101486206
#              training accuracy with pixel by pixel: 0.9871116280555725
#              test accuracy with jaccard: 0.9723364114761353
#              test accuracy with dice: 0.9859040379524231
#              test accuracy with pixel by pixel: 0.9856767654418945
# Step 864     training accuracy with jaccard: 0.9745895862579346
#              training accuracy with dice: 0.987066924571991
#              training accuracy with pixel by pixel: 0.9870370030403137
#              test accuracy with jaccard: 0.975378692150116
#              test accuracy with dice: 0.9875545501708984
#              test accuracy with pixel by pixel: 0.9871602654457092
# Step 882     training accuracy with jaccard: 0.97532719373703
#              training accuracy with dice: 0.9874551296234131
#              training accuracy with pixel by pixel: 0.9874050617218018
#              test accuracy with jaccard: 0.9727350473403931
#              test accuracy with dice: 0.98606938123703
#              test accuracy with pixel by pixel: 0.986086368560791
# Step 900     training accuracy with jaccard: 0.9739980697631836
#              training accuracy with dice: 0.9868106842041016
#              training accuracy with pixel by pixel: 0.986595869064331
#              test accuracy with jaccard: 0.9727974534034729
#              test accuracy with dice: 0.9862015843391418
#              test accuracy with pixel by pixel: 0.985805332660675
# Step 918     training accuracy with jaccard: 0.9755616784095764
#              training accuracy with dice: 0.9876007437705994
#              training accuracy with pixel by pixel: 0.9875587821006775
#              test accuracy with jaccard: 0.971145510673523
#              test accuracy with dice: 0.9852313995361328
#              test accuracy with pixel by pixel: 0.9842890501022339
# Step 936     training accuracy with jaccard: 0.9761087894439697
#              training accuracy with dice: 0.9879248142242432
#              training accuracy with pixel by pixel: 0.9877406358718872
#              test accuracy with jaccard: 0.9745906591415405
#              test accuracy with dice: 0.9871489405632019
#              test accuracy with pixel by pixel: 0.9862620830535889
# Step 954     training accuracy with jaccard: 0.9749964475631714
#              training accuracy with dice: 0.9873042702674866
#              training accuracy with pixel by pixel: 0.9872385859489441
#              test accuracy with jaccard: 0.9719040989875793
#              test accuracy with dice: 0.9855645298957825
#              test accuracy with pixel by pixel: 0.9857854843139648
# Step 972     training accuracy with jaccard: 0.976146399974823
#              training accuracy with dice: 0.9879283905029297
#              training accuracy with pixel by pixel: 0.987899124622345
#              test accuracy with jaccard: 0.9739518165588379
#              test accuracy with dice: 0.986842155456543
#              test accuracy with pixel by pixel: 0.9855583906173706
# Step 990     training accuracy with jaccard: 0.9760460257530212
#              training accuracy with dice: 0.9878237247467041
#              training accuracy with pixel by pixel: 0.9878199100494385
#              test accuracy with jaccard: 0.9745395183563232
#              test accuracy with dice: 0.9870122075080872
#              test accuracy with pixel by pixel: 0.9867326617240906
# Step 1008    training accuracy with jaccard: 0.9766542911529541
#              training accuracy with dice: 0.9881210327148438
#              training accuracy with pixel by pixel: 0.9880449771881104
#              test accuracy with jaccard: 0.9761399030685425
#              test accuracy with dice: 0.9878253936767578
#              test accuracy with pixel by pixel: 0.987719714641571
# Step 1026    training accuracy with jaccard: 0.9757207036018372
#              training accuracy with dice: 0.9877116084098816
#              training accuracy with pixel by pixel: 0.9874737858772278
#              test accuracy with jaccard: 0.9754183292388916
#              test accuracy with dice: 0.9874954223632812
#              test accuracy with pixel by pixel: 0.9871809482574463
# Step 1044    training accuracy with jaccard: 0.9751622676849365
#              training accuracy with dice: 0.9873767495155334
#              training accuracy with pixel by pixel: 0.9873108267784119
#              test accuracy with jaccard: 0.9776866436004639
#              test accuracy with dice: 0.9887657165527344
#              test accuracy with pixel by pixel: 0.9886371493339539
# Step 1062    training accuracy with jaccard: 0.9768877029418945
#              training accuracy with dice: 0.988246500492096
#              training accuracy with pixel by pixel: 0.9882268905639648
#              test accuracy with jaccard: 0.9743536710739136
#              test accuracy with dice: 0.9868214726448059
#              test accuracy with pixel by pixel: 0.9870094656944275
# Step 1080    training accuracy with jaccard: 0.9766747951507568
#              training accuracy with dice: 0.9881184697151184
#              training accuracy with pixel by pixel: 0.9881335496902466
#              test accuracy with jaccard: 0.9760318398475647
#              test accuracy with dice: 0.9877573847770691
#              test accuracy with pixel by pixel: 0.9874669313430786
# Step 1098    training accuracy with jaccard: 0.9770363569259644
#              training accuracy with dice: 0.988366425037384
#              training accuracy with pixel by pixel: 0.9883327484130859
#              test accuracy with jaccard: 0.9741095304489136
#              test accuracy with dice: 0.9869508743286133
#              test accuracy with pixel by pixel: 0.9869474172592163
# Step 1116    training accuracy with jaccard: 0.9772284030914307
#              training accuracy with dice: 0.98850417137146
#              training accuracy with pixel by pixel: 0.9884204864501953
#              test accuracy with jaccard: 0.9746192097663879
#              test accuracy with dice: 0.9871085286140442
#              test accuracy with pixel by pixel: 0.9869718551635742
# Step 1134    training accuracy with jaccard: 0.9754201173782349
#              training accuracy with dice: 0.9874856472015381
#              training accuracy with pixel by pixel: 0.987558901309967
#              test accuracy with jaccard: 0.9761378169059753
#              test accuracy with dice: 0.9878625869750977
#              test accuracy with pixel by pixel: 0.9875754117965698
# Step 1152    training accuracy with jaccard: 0.977423906326294
#              training accuracy with dice: 0.9885671138763428
#              training accuracy with pixel by pixel: 0.9884750843048096
#              test accuracy with jaccard: 0.9757013320922852
#              test accuracy with dice: 0.9878025054931641
#              test accuracy with pixel by pixel: 0.9872704744338989
# Step 1170    training accuracy with jaccard: 0.9765097498893738
#              training accuracy with dice: 0.9880644679069519
#              training accuracy with pixel by pixel: 0.9879894256591797
#              test accuracy with jaccard: 0.9756721258163452
#              test accuracy with dice: 0.9878203272819519
#              test accuracy with pixel by pixel: 0.987038254737854
# Step 1188    training accuracy with jaccard: 0.9774573445320129
#              training accuracy with dice: 0.9886256456375122
#              training accuracy with pixel by pixel: 0.988541841506958
#              test accuracy with jaccard: 0.9757309556007385
#              test accuracy with dice: 0.9876499176025391
#              test accuracy with pixel by pixel: 0.9874496459960938
# Step 1206    training accuracy with jaccard: 0.9759250283241272
#              training accuracy with dice: 0.9877753853797913
#              training accuracy with pixel by pixel: 0.9875426888465881
#              test accuracy with jaccard: 0.9766817092895508
#              test accuracy with dice: 0.9881502985954285
#              test accuracy with pixel by pixel: 0.9879028797149658
# Step 1224    training accuracy with jaccard: 0.9769256114959717
#              training accuracy with dice: 0.9882920384407043
#              training accuracy with pixel by pixel: 0.9882939457893372
#              test accuracy with jaccard: 0.974892258644104
#              test accuracy with dice: 0.9870875477790833
#              test accuracy with pixel by pixel: 0.9867137670516968
# Step 1242    training accuracy with jaccard: 0.9761044979095459
#              training accuracy with dice: 0.987980306148529
#              training accuracy with pixel by pixel: 0.9877245426177979
#              test accuracy with jaccard: 0.9779542684555054
#              test accuracy with dice: 0.988872230052948
#              test accuracy with pixel by pixel: 0.988579273223877
# Step 1260    training accuracy with jaccard: 0.9774431586265564
#              training accuracy with dice: 0.9885313510894775
#              training accuracy with pixel by pixel: 0.9885427951812744
#              test accuracy with jaccard: 0.9762794971466064
#              test accuracy with dice: 0.9879560470581055
#              test accuracy with pixel by pixel: 0.9875743985176086
# Step 1278    training accuracy with jaccard: 0.9779207706451416
#              training accuracy with dice: 0.9888068437576294
#              training accuracy with pixel by pixel: 0.9887171983718872
#              test accuracy with jaccard: 0.9783403277397156
#              test accuracy with dice: 0.9890251159667969
#              test accuracy with pixel by pixel: 0.9891102313995361
# Step 1296    training accuracy with jaccard: 0.9782702326774597
#              training accuracy with dice: 0.9890232086181641
#              training accuracy with pixel by pixel: 0.9889898300170898
#              test accuracy with jaccard: 0.978908360004425
#              test accuracy with dice: 0.9892870783805847
#              test accuracy with pixel by pixel: 0.989440381526947
# Step 1314    training accuracy with jaccard: 0.9774851202964783
#              training accuracy with dice: 0.98856520652771
#              training accuracy with pixel by pixel: 0.9885894060134888
#              test accuracy with jaccard: 0.9772508144378662
#              test accuracy with dice: 0.9885063171386719
#              test accuracy with pixel by pixel: 0.9882453083992004
# Step 1332    training accuracy with jaccard: 0.9775367379188538
#              training accuracy with dice: 0.9886152744293213
#              training accuracy with pixel by pixel: 0.9885836839675903
#              test accuracy with jaccard: 0.976095974445343
#              test accuracy with dice: 0.9878432154655457
#              test accuracy with pixel by pixel: 0.9881346225738525
# Step 1350    training accuracy with jaccard: 0.9786106944084167
#              training accuracy with dice: 0.9892014265060425
#              training accuracy with pixel by pixel: 0.9891392588615417
#              test accuracy with jaccard: 0.976576566696167
#              test accuracy with dice: 0.9880380630493164
#              test accuracy with pixel by pixel: 0.9881612658500671
# Step 1368    training accuracy with jaccard: 0.977859616279602
#              training accuracy with dice: 0.9888576865196228
#              training accuracy with pixel by pixel: 0.988750696182251
#              test accuracy with jaccard: 0.9775444269180298
#              test accuracy with dice: 0.9885870814323425
#              test accuracy with pixel by pixel: 0.9889984726905823
# Step 1386    training accuracy with jaccard: 0.9775362014770508
#              training accuracy with dice: 0.9885959625244141
#              training accuracy with pixel by pixel: 0.9886026382446289
#              test accuracy with jaccard: 0.9771726727485657
#              test accuracy with dice: 0.9883320927619934
#              test accuracy with pixel by pixel: 0.9887220859527588
# Step 1404    training accuracy with jaccard: 0.9781890511512756
#              training accuracy with dice: 0.9890109300613403
#              training accuracy with pixel by pixel: 0.9888529181480408
#              test accuracy with jaccard: 0.9764389395713806
#              test accuracy with dice: 0.9881951212882996
#              test accuracy with pixel by pixel: 0.988072395324707
# Step 1422    training accuracy with jaccard: 0.9787009358406067
#              training accuracy with dice: 0.9892117977142334
#              training accuracy with pixel by pixel: 0.9891833066940308
#              test accuracy with jaccard: 0.9777799248695374
#              test accuracy with dice: 0.9886500239372253
#              test accuracy with pixel by pixel: 0.9883260726928711
# Step 1440    training accuracy with jaccard: 0.9776671528816223
#              training accuracy with dice: 0.98867267370224
#              training accuracy with pixel by pixel: 0.9886155724525452
#              test accuracy with jaccard: 0.9784824848175049
#              test accuracy with dice: 0.9892416000366211
#              test accuracy with pixel by pixel: 0.9891833066940308
# Step 1458    training accuracy with jaccard: 0.9775661826133728
#              training accuracy with dice: 0.9887292385101318
#              training accuracy with pixel by pixel: 0.9885313510894775
#              test accuracy with jaccard: 0.9766373634338379
#              test accuracy with dice: 0.9880857467651367
#              test accuracy with pixel by pixel: 0.9880518317222595
# Step 1476    training accuracy with jaccard: 0.9781255722045898
#              training accuracy with dice: 0.9889293313026428
#              training accuracy with pixel by pixel: 0.9887979030609131
#              test accuracy with jaccard: 0.9771221280097961
#              test accuracy with dice: 0.9885075688362122
#              test accuracy with pixel by pixel: 0.988184928894043
# Step 1494    training accuracy with jaccard: 0.9785570502281189
#              training accuracy with dice: 0.98917555809021
#              training accuracy with pixel by pixel: 0.9890984296798706
#              test accuracy with jaccard: 0.9749879837036133
#              test accuracy with dice: 0.9872137904167175
#              test accuracy with pixel by pixel: 0.9874024987220764
# Step 1512    training accuracy with jaccard: 0.9784862995147705
#              training accuracy with dice: 0.9891601204872131
#              training accuracy with pixel by pixel: 0.9890897274017334
#              test accuracy with jaccard: 0.9787502884864807
#              test accuracy with dice: 0.9894482493400574
#              test accuracy with pixel by pixel: 0.9894583225250244
# Step 1530    training accuracy with jaccard: 0.9785429835319519
#              training accuracy with dice: 0.9891696572303772
#              training accuracy with pixel by pixel: 0.989146888256073
#              test accuracy with jaccard: 0.9773623943328857
#              test accuracy with dice: 0.9885568618774414
#              test accuracy with pixel by pixel: 0.9886549711227417
# Step 1548    training accuracy with jaccard: 0.9780166149139404
#              training accuracy with dice: 0.9888074398040771
#              training accuracy with pixel by pixel: 0.988788902759552
#              test accuracy with jaccard: 0.9776923656463623
#              test accuracy with dice: 0.9887459874153137
#              test accuracy with pixel by pixel: 0.9884634017944336
# Step 1566    training accuracy with jaccard: 0.9779804944992065
#              training accuracy with dice: 0.98879075050354
#              training accuracy with pixel by pixel: 0.9888013005256653
#              test accuracy with jaccard: 0.9778366088867188
#              test accuracy with dice: 0.9887263178825378
#              test accuracy with pixel by pixel: 0.9881526827812195
# Step 1584    training accuracy with jaccard: 0.9785934090614319
#              training accuracy with dice: 0.9892029166221619
#              training accuracy with pixel by pixel: 0.9891056418418884
#              test accuracy with jaccard: 0.9772282242774963
#              test accuracy with dice: 0.9886150360107422
#              test accuracy with pixel by pixel: 0.9876660704612732
# Step 1602    training accuracy with jaccard: 0.9787455797195435
#              training accuracy with dice: 0.9892143607139587
#              training accuracy with pixel by pixel: 0.9891427159309387
#              test accuracy with jaccard: 0.977176308631897
#              test accuracy with dice: 0.9883737564086914
#              test accuracy with pixel by pixel: 0.988571047782898
# Step 1620    training accuracy with jaccard: 0.9793036580085754
#              training accuracy with dice: 0.9895670413970947
#              training accuracy with pixel by pixel: 0.9894506931304932
#              test accuracy with jaccard: 0.9781925678253174
#              test accuracy with dice: 0.9888973236083984
#              test accuracy with pixel by pixel: 0.9891711473464966
# Step 1638    training accuracy with jaccard: 0.9785496592521667
#              training accuracy with dice: 0.9891276955604553
#              training accuracy with pixel by pixel: 0.989150881767273
#              test accuracy with jaccard: 0.9770853519439697
#              test accuracy with dice: 0.9882780909538269
#              test accuracy with pixel by pixel: 0.9879785180091858
# Step 1656    training accuracy with jaccard: 0.9788825511932373
#              training accuracy with dice: 0.9893879294395447
#              training accuracy with pixel by pixel: 0.9893020987510681
#              test accuracy with jaccard: 0.9766513109207153
#              test accuracy with dice: 0.9882284998893738
#              test accuracy with pixel by pixel: 0.9874445796012878
# Step 1674    training accuracy with jaccard: 0.978882372379303
#              training accuracy with dice: 0.9893595576286316
#              training accuracy with pixel by pixel: 0.9892843961715698
#              test accuracy with jaccard: 0.9793028831481934
#              test accuracy with dice: 0.9894739985466003
#              test accuracy with pixel by pixel: 0.9894298911094666
# Step 1692    training accuracy with jaccard: 0.9790816903114319
#              training accuracy with dice: 0.9894158840179443
#              training accuracy with pixel by pixel: 0.9893200993537903
#              test accuracy with jaccard: 0.9798547625541687
#              test accuracy with dice: 0.9898598790168762
#              test accuracy with pixel by pixel: 0.9900829195976257
# Step 1710    training accuracy with jaccard: 0.9788270592689514
#              training accuracy with dice: 0.9893167018890381
#              training accuracy with pixel by pixel: 0.9891406297683716
#              test accuracy with jaccard: 0.9778752326965332
#              test accuracy with dice: 0.9887329936027527
#              test accuracy with pixel by pixel: 0.989078938961029
# Step 1728    training accuracy with jaccard: 0.9790758490562439
#              training accuracy with dice: 0.9894707798957825
#              training accuracy with pixel by pixel: 0.9893132448196411
#              test accuracy with jaccard: 0.9793562889099121
#              test accuracy with dice: 0.9896084666252136
#              test accuracy with pixel by pixel: 0.9891384840011597
# Step 1746    training accuracy with jaccard: 0.9794209003448486
#              training accuracy with dice: 0.9896240234375
#              training accuracy with pixel by pixel: 0.9895466566085815
#              test accuracy with jaccard: 0.976559042930603
#              test accuracy with dice: 0.9881086349487305
#              test accuracy with pixel by pixel: 0.9875197410583496
# Step 1764    training accuracy with jaccard: 0.9780502319335938
#              training accuracy with dice: 0.9889267683029175
#              training accuracy with pixel by pixel: 0.9887834191322327
#              test accuracy with jaccard: 0.9785851836204529
#              test accuracy with dice: 0.989090621471405
#              test accuracy with pixel by pixel: 0.9891422986984253
# Step 1782    training accuracy with jaccard: 0.9794393181800842
#              training accuracy with dice: 0.9896098375320435
#              training accuracy with pixel by pixel: 0.9895009994506836
#              test accuracy with jaccard: 0.9756124019622803
#              test accuracy with dice: 0.9877188801765442
#              test accuracy with pixel by pixel: 0.9882068037986755
# Step 1800    training accuracy with jaccard: 0.9794008731842041
#              training accuracy with dice: 0.9896076917648315
#              training accuracy with pixel by pixel: 0.9895159602165222
#              test accuracy with jaccard: 0.9783806800842285
#              test accuracy with dice: 0.9889707565307617
#              test accuracy with pixel by pixel: 0.9889433979988098
# Step 1818    training accuracy with jaccard: 0.978226363658905
#              training accuracy with dice: 0.9890526533126831
#              training accuracy with pixel by pixel: 0.9887521266937256
#              test accuracy with jaccard: 0.9785741567611694
#              test accuracy with dice: 0.9890702366828918
#              test accuracy with pixel by pixel: 0.9891594648361206
# Step 1836    training accuracy with jaccard: 0.97832190990448
#              training accuracy with dice: 0.9890412092208862
#              training accuracy with pixel by pixel: 0.9890443086624146
#              test accuracy with jaccard: 0.9764479398727417
#              test accuracy with dice: 0.9879801869392395
#              test accuracy with pixel by pixel: 0.9884430170059204
# Step 1854    training accuracy with jaccard: 0.9790417551994324
#              training accuracy with dice: 0.989380955696106
#              training accuracy with pixel by pixel: 0.9892616271972656
#              test accuracy with jaccard: 0.978610634803772
#              test accuracy with dice: 0.9891631007194519
#              test accuracy with pixel by pixel: 0.9896621704101562
# Step 1872    training accuracy with jaccard: 0.9791408181190491
#              training accuracy with dice: 0.9895394444465637
#              training accuracy with pixel by pixel: 0.9893897175788879
#              test accuracy with jaccard: 0.9748184680938721
#              test accuracy with dice: 0.987193763256073
#              test accuracy with pixel by pixel: 0.9882270097732544
# Step 1890    training accuracy with jaccard: 0.9777891635894775
#              training accuracy with dice: 0.9887362718582153
#              training accuracy with pixel by pixel: 0.9886752367019653
#              test accuracy with jaccard: 0.9772695302963257
#              test accuracy with dice: 0.9886319041252136
#              test accuracy with pixel by pixel: 0.988800585269928
# Step 1908    training accuracy with jaccard: 0.9788388013839722
#              training accuracy with dice: 0.9893001914024353
#              training accuracy with pixel by pixel: 0.989313542842865
#              test accuracy with jaccard: 0.979241669178009
#              test accuracy with dice: 0.9894259572029114
#              test accuracy with pixel by pixel: 0.9895111918449402
# Step 1926    training accuracy with jaccard: 0.9791022539138794
#              training accuracy with dice: 0.989477813243866
#              training accuracy with pixel by pixel: 0.9894163608551025
#              test accuracy with jaccard: 0.9785539507865906
#              test accuracy with dice: 0.9891297221183777
#              test accuracy with pixel by pixel: 0.9887747168540955
# Step 1944    training accuracy with jaccard: 0.979492723941803
#              training accuracy with dice: 0.9896681308746338
#              training accuracy with pixel by pixel: 0.9895749688148499
#              test accuracy with jaccard: 0.9776649475097656
#              test accuracy with dice: 0.9886503219604492
#              test accuracy with pixel by pixel: 0.9888054728507996
# Step 1962    training accuracy with jaccard: 0.978557288646698
#              training accuracy with dice: 0.9891631007194519
#              training accuracy with pixel by pixel: 0.9891076683998108
#              test accuracy with jaccard: 0.9786648750305176
#              test accuracy with dice: 0.9892498850822449
#              test accuracy with pixel by pixel: 0.9893372058868408
# Step 1980    training accuracy with jaccard: 0.9792342782020569
#              training accuracy with dice: 0.9894907474517822
#              training accuracy with pixel by pixel: 0.9894307255744934
#              test accuracy with jaccard: 0.9795446395874023
#              test accuracy with dice: 0.9895709156990051
#              test accuracy with pixel by pixel: 0.9898375868797302
# Step 1998    training accuracy with jaccard: 0.9794437885284424
#              training accuracy with dice: 0.9895918369293213
#              training accuracy with pixel by pixel: 0.9895727634429932
#              test accuracy with jaccard: 0.9800498485565186
#              test accuracy with dice: 0.9899489283561707
#              test accuracy with pixel by pixel: 0.9900038242340088
# Step 2016    training accuracy with jaccard: 0.9803450703620911
#              training accuracy with dice: 0.9900535941123962
#              training accuracy with pixel by pixel: 0.9900586009025574
#              test accuracy with jaccard: 0.9779244065284729
#              test accuracy with dice: 0.9887526631355286
#              test accuracy with pixel by pixel: 0.9888962507247925
# Step 2034    training accuracy with jaccard: 0.9795554280281067
#              training accuracy with dice: 0.9897149205207825
#              training accuracy with pixel by pixel: 0.9896320700645447
#              test accuracy with jaccard: 0.9777693748474121
#              test accuracy with dice: 0.9886687397956848
#              test accuracy with pixel by pixel: 0.9890623092651367
# Step 2052    training accuracy with jaccard: 0.9796656370162964
#              training accuracy with dice: 0.9897838234901428
#              training accuracy with pixel by pixel: 0.9897181987762451
#              test accuracy with jaccard: 0.9776113629341125
#              test accuracy with dice: 0.9887606501579285
#              test accuracy with pixel by pixel: 0.9882700443267822
# Step 2070    training accuracy with jaccard: 0.9797340035438538
#              training accuracy with dice: 0.9898166656494141
#              training accuracy with pixel by pixel: 0.9896290302276611
#              test accuracy with jaccard: 0.9791275262832642
#              test accuracy with dice: 0.9893452525138855
#              test accuracy with pixel by pixel: 0.9893009662628174
# Step 2088    training accuracy with jaccard: 0.9784066081047058
#              training accuracy with dice: 0.9890596866607666
#              training accuracy with pixel by pixel: 0.9889799952507019
#              test accuracy with jaccard: 0.9779990315437317
#              test accuracy with dice: 0.9889472126960754
#              test accuracy with pixel by pixel: 0.9886230826377869
# Step 2106    training accuracy with jaccard: 0.9798309803009033
#              training accuracy with dice: 0.9898003339767456
#              training accuracy with pixel by pixel: 0.9897828698158264
#              test accuracy with jaccard: 0.9769477844238281
#              test accuracy with dice: 0.9883810877799988
#              test accuracy with pixel by pixel: 0.9885771870613098
# Step 2124    training accuracy with jaccard: 0.9790999293327332
#              training accuracy with dice: 0.9895225167274475
#              training accuracy with pixel by pixel: 0.9893726706504822
#              test accuracy with jaccard: 0.9784302711486816
#              test accuracy with dice: 0.9890820384025574
#              test accuracy with pixel by pixel: 0.9888043403625488
# Step 2142    training accuracy with jaccard: 0.9784472584724426
#              training accuracy with dice: 0.9890749454498291
#              training accuracy with pixel by pixel: 0.9890913367271423
#              test accuracy with jaccard: 0.9779712557792664
#              test accuracy with dice: 0.98899906873703
#              test accuracy with pixel by pixel: 0.988735556602478
# Step 2160    training accuracy with jaccard: 0.9800006151199341
#              training accuracy with dice: 0.9899063110351562
#              training accuracy with pixel by pixel: 0.9898569583892822
#              test accuracy with jaccard: 0.9772953987121582
#              test accuracy with dice: 0.9885311126708984
#              test accuracy with pixel by pixel: 0.9880372285842896
# Step 2178    training accuracy with jaccard: 0.9804346561431885
#              training accuracy with dice: 0.9901180267333984
#              training accuracy with pixel by pixel: 0.9900846481323242
#              test accuracy with jaccard: 0.9789019227027893
#              test accuracy with dice: 0.989268958568573
#              test accuracy with pixel by pixel: 0.9893821477890015
# Step 2196    training accuracy with jaccard: 0.980675995349884
#              training accuracy with dice: 0.9902248382568359
#              training accuracy with pixel by pixel: 0.9901645183563232
#              test accuracy with jaccard: 0.9775323271751404
#              test accuracy with dice: 0.9885947108268738
#              test accuracy with pixel by pixel: 0.9883347153663635
# Step 2214    training accuracy with jaccard: 0.9806653261184692
#              training accuracy with dice: 0.99024897813797
#              training accuracy with pixel by pixel: 0.9901553392410278
#              test accuracy with jaccard: 0.97850102186203
#              test accuracy with dice: 0.9890883564949036
#              test accuracy with pixel by pixel: 0.9888572692871094
# Step 2232    training accuracy with jaccard: 0.9793747663497925
#              training accuracy with dice: 0.9895638227462769
#              training accuracy with pixel by pixel: 0.9895455837249756
#              test accuracy with jaccard: 0.9805005788803101
#              test accuracy with dice: 0.9901263117790222
#              test accuracy with pixel by pixel: 0.9904306530952454
# Step 2250    training accuracy with jaccard: 0.9794396162033081
#              training accuracy with dice: 0.9896149039268494
#              training accuracy with pixel by pixel: 0.9896027445793152
#              test accuracy with jaccard: 0.9788936376571655
#              test accuracy with dice: 0.9893315434455872
#              test accuracy with pixel by pixel: 0.9891749024391174
# Step 2268    training accuracy with jaccard: 0.9792836308479309
#              training accuracy with dice: 0.9894697666168213
#              training accuracy with pixel by pixel: 0.9894549250602722
#              test accuracy with jaccard: 0.979193925857544
#              test accuracy with dice: 0.9894332885742188
#              test accuracy with pixel by pixel: 0.9892767667770386
# Step 2286    training accuracy with jaccard: 0.9798865914344788
#              training accuracy with dice: 0.9897774457931519
#              training accuracy with pixel by pixel: 0.9897648692131042
# ...
# Step 2862    training accuracy with jaccard: 0.9803448915481567
#              training accuracy with dice: 0.9901057481765747
#              training accuracy with pixel by pixel: 0.9900472164154053
#              test accuracy with jaccard: 0.9769730567932129
#              test accuracy with dice: 0.9882602691650391
#              test accuracy with pixel by pixel: 0.9885139465332031
# Step 2880    training accuracy with jaccard: 0.9808520078659058
#              training accuracy with dice: 0.990347146987915
#              training accuracy with pixel by pixel: 0.9902760982513428
#              test accuracy with jaccard: 0.9793189764022827
#              test accuracy with dice: 0.989482581615448
#              test accuracy with pixel by pixel: 0.989691436290741
# Step 2898    training accuracy with jaccard: 0.9811066389083862
#              training accuracy with dice: 0.9905081987380981
#              training accuracy with pixel by pixel: 0.9905305504798889
#              test accuracy with jaccard: 0.9810417890548706
#              test accuracy with dice: 0.9905754923820496
#              test accuracy with pixel by pixel: 0.9901537895202637
# Step 2916    training accuracy with jaccard: 0.9811743497848511
#              training accuracy with dice: 0.9905446171760559
#              training accuracy with pixel by pixel: 0.9904558658599854
#              test accuracy with jaccard: 0.9802444577217102
#              test accuracy with dice: 0.9900522232055664
#              test accuracy with pixel by pixel: 0.990181565284729
# Step 2934    training accuracy with jaccard: 0.9812083840370178
#              training accuracy with dice: 0.9905717372894287
#              training accuracy with pixel by pixel: 0.9904736280441284
#              test accuracy with jaccard: 0.9807830452919006
#              test accuracy with dice: 0.9903818964958191
#              test accuracy with pixel by pixel: 0.9903993606567383
# Step 2952    training accuracy with jaccard: 0.980840265750885
#              training accuracy with dice: 0.9903793334960938
#              training accuracy with pixel by pixel: 0.9902936220169067
#              test accuracy with jaccard: 0.9788761138916016
#              test accuracy with dice: 0.9892371296882629
#              test accuracy with pixel by pixel: 0.9892793893814087
# Step 2970    training accuracy with jaccard: 0.9813908338546753
#              training accuracy with dice: 0.9906135201454163
#              training accuracy with pixel by pixel: 0.9905648827552795
#              test accuracy with jaccard: 0.9787954688072205
#              test accuracy with dice: 0.9892873764038086
#              test accuracy with pixel by pixel: 0.989331841468811
# Step 2988    training accuracy with jaccard: 0.9801457524299622
#              training accuracy with dice: 0.989983856678009
#              training accuracy with pixel by pixel: 0.9898957014083862
#              test accuracy with jaccard: 0.9805638790130615
#              test accuracy with dice: 0.9902079701423645
#              test accuracy with pixel by pixel: 0.989970326423645
# Step 3006    training accuracy with jaccard: 0.9799973368644714
#              training accuracy with dice: 0.9899461269378662
#              training accuracy with pixel by pixel: 0.9898426532745361
#              test accuracy with jaccard: 0.9788815975189209
#              test accuracy with dice: 0.9891834259033203
#              test accuracy with pixel by pixel: 0.9897798299789429
# Step 3024    training accuracy with jaccard: 0.980606198310852
#              training accuracy with dice: 0.9902970790863037
#              training accuracy with pixel by pixel: 0.9901279807090759
#              test accuracy with jaccard: 0.9800947308540344
#              test accuracy with dice: 0.9900500178337097
#              test accuracy with pixel by pixel: 0.9901244044303894
# Step 3042    training accuracy with jaccard: 0.9805075526237488
#              training accuracy with dice: 0.99017333984375
#              training accuracy with pixel by pixel: 0.9901145100593567
#              test accuracy with jaccard: 0.9777607917785645
#              test accuracy with dice: 0.9887335896492004
#              test accuracy with pixel by pixel: 0.9888086318969727
# Step 3060    training accuracy with jaccard: 0.9815934300422668
#              training accuracy with dice: 0.9907107949256897
#              training accuracy with pixel by pixel: 0.9907500147819519
#              test accuracy with jaccard: 0.9792587757110596
#              test accuracy with dice: 0.9894616007804871
#              test accuracy with pixel by pixel: 0.9895616769790649
# Step 3078    training accuracy with jaccard: 0.98096764087677
#              training accuracy with dice: 0.9904253482818604
#              training accuracy with pixel by pixel: 0.9903600215911865
#              test accuracy with jaccard: 0.9802422523498535
#              test accuracy with dice: 0.9900245666503906
#              test accuracy with pixel by pixel: 0.990302324295044
# Step 3096    training accuracy with jaccard: 0.9813878536224365
#              training accuracy with dice: 0.9906226396560669
#              training accuracy with pixel by pixel: 0.9905601143836975
#              test accuracy with jaccard: 0.9783703088760376
#              test accuracy with dice: 0.9889945983886719
#              test accuracy with pixel by pixel: 0.9893076419830322
# Step 3114    training accuracy with jaccard: 0.9801757335662842
#              training accuracy with dice: 0.9900211691856384
#              training accuracy with pixel by pixel: 0.9899534583091736
#              test accuracy with jaccard: 0.9808660745620728
#              test accuracy with dice: 0.9903287887573242
#              test accuracy with pixel by pixel: 0.9907312393188477
# Step 3132    training accuracy with jaccard: 0.9808337688446045
#              training accuracy with dice: 0.9903488159179688
#              training accuracy with pixel by pixel: 0.9902547001838684
#              test accuracy with jaccard: 0.9800583720207214
#              test accuracy with dice: 0.9898433685302734
#              test accuracy with pixel by pixel: 0.9900256991386414
# Step 3150    training accuracy with jaccard: 0.9813289642333984
#              training accuracy with dice: 0.9905825853347778
#              training accuracy with pixel by pixel: 0.9905763268470764
#              test accuracy with jaccard: 0.9812272787094116
#              test accuracy with dice: 0.9905818104743958
#              test accuracy with pixel by pixel: 0.9907180070877075
# Step 3168    training accuracy with jaccard: 0.9811307191848755
#              training accuracy with dice: 0.9905745387077332
#              training accuracy with pixel by pixel: 0.9904772639274597
#              test accuracy with jaccard: 0.9794958829879761
#              test accuracy with dice: 0.9896910786628723
#              test accuracy with pixel by pixel: 0.990189254283905
# Step 3186    training accuracy with jaccard: 0.980955958366394
#              training accuracy with dice: 0.99040287733078
#              training accuracy with pixel by pixel: 0.9904178977012634
#              test accuracy with jaccard: 0.9803211092948914
#              test accuracy with dice: 0.9899988174438477
#              test accuracy with pixel by pixel: 0.9899871349334717
# Step 3204    training accuracy with jaccard: 0.9808363318443298
#              training accuracy with dice: 0.990405797958374
#              training accuracy with pixel by pixel: 0.9902026057243347
#              test accuracy with jaccard: 0.9780882596969604
#              test accuracy with dice: 0.9890219569206238
#              test accuracy with pixel by pixel: 0.988967776298523
# Step 3222    training accuracy with jaccard: 0.9803124666213989
#              training accuracy with dice: 0.9900137782096863
#              training accuracy with pixel by pixel: 0.9900000691413879
#              test accuracy with jaccard: 0.979119062423706
#              test accuracy with dice: 0.9894164204597473
#              test accuracy with pixel by pixel: 0.9891366958618164
# Step 3240    training accuracy with jaccard: 0.9804364442825317
#              training accuracy with dice: 0.99015212059021
#              training accuracy with pixel by pixel: 0.9900324940681458
#              test accuracy with jaccard: 0.979865550994873
#              test accuracy with dice: 0.9897918701171875
#              test accuracy with pixel by pixel: 0.9899191856384277
# Step 3258    training accuracy with jaccard: 0.9806215763092041
#              training accuracy with dice: 0.990197479724884
#              training accuracy with pixel by pixel: 0.9901467561721802
#              test accuracy with jaccard: 0.9773687124252319
#              test accuracy with dice: 0.988530158996582
#              test accuracy with pixel by pixel: 0.988316535949707
# Step 3276    training accuracy with jaccard: 0.9802141189575195
#              training accuracy with dice: 0.9899817705154419
#              training accuracy with pixel by pixel: 0.989943265914917
#              test accuracy with jaccard: 0.9791851043701172
#              test accuracy with dice: 0.9896065592765808
#              test accuracy with pixel by pixel: 0.9896343946456909
# Step 3294    training accuracy with jaccard: 0.981086015701294
#              training accuracy with dice: 0.9904606938362122
#              training accuracy with pixel by pixel: 0.9904739856719971
#              test accuracy with jaccard: 0.9817037582397461
#              test accuracy with dice: 0.9908590316772461
#              test accuracy with pixel by pixel: 0.9913226366043091
# Step 3312    training accuracy with jaccard: 0.9811114072799683
#              training accuracy with dice: 0.9904693961143494
#              training accuracy with pixel by pixel: 0.9904252290725708
#              test accuracy with jaccard: 0.9803839921951294
#              test accuracy with dice: 0.9901609420776367
#              test accuracy with pixel by pixel: 0.9900377988815308
# Step 3330    training accuracy with jaccard: 0.9809414744377136
#              training accuracy with dice: 0.9903604984283447
#              training accuracy with pixel by pixel: 0.9903110861778259
#              test accuracy with jaccard: 0.9792943000793457
#              test accuracy with dice: 0.9897635579109192
#              test accuracy with pixel by pixel: 0.9894031882286072
# Step 3348    training accuracy with jaccard: 0.9803076982498169
#              training accuracy with dice: 0.9901152849197388
#              training accuracy with pixel by pixel: 0.99000483751297
#              test accuracy with jaccard: 0.9798175096511841
#              test accuracy with dice: 0.9898405075073242
#              test accuracy with pixel by pixel: 0.9896076917648315
# Step 3366    training accuracy with jaccard: 0.9802694320678711
#              training accuracy with dice: 0.9900171756744385
#              training accuracy with pixel by pixel: 0.9900178909301758
#              test accuracy with jaccard: 0.9789373874664307
#              test accuracy with dice: 0.9893999099731445
#              test accuracy with pixel by pixel: 0.9893361330032349
# Step 3384    training accuracy with jaccard: 0.9807606935501099
#              training accuracy with dice: 0.9903144836425781
#              training accuracy with pixel by pixel: 0.9902708530426025
#              test accuracy with jaccard: 0.9809502363204956
#              test accuracy with dice: 0.9903681874275208
#              test accuracy with pixel by pixel: 0.9902185201644897
# Step 3402    training accuracy with jaccard: 0.9814353585243225
#              training accuracy with dice: 0.9907315373420715
#              training accuracy with pixel by pixel: 0.9905964732170105
#              test accuracy with jaccard: 0.9793508052825928
#              test accuracy with dice: 0.9893996119499207
#              test accuracy with pixel by pixel: 0.989250898361206
# Step 3420    training accuracy with jaccard: 0.9813797473907471
#              training accuracy with dice: 0.9906738996505737
#              training accuracy with pixel by pixel: 0.9906071424484253
#              test accuracy with jaccard: 0.9799237847328186
#              test accuracy with dice: 0.9897750020027161
#              test accuracy with pixel by pixel: 0.989867091178894
# Step 3438    training accuracy with jaccard: 0.980911910533905
#              training accuracy with dice: 0.9904060363769531
#              training accuracy with pixel by pixel: 0.9903805255889893
#              test accuracy with jaccard: 0.9808022975921631
#              test accuracy with dice: 0.9905071258544922
#              test accuracy with pixel by pixel: 0.9904581308364868
# Step 3456    training accuracy with jaccard: 0.9807349443435669
#              training accuracy with dice: 0.9903015494346619
#              training accuracy with pixel by pixel: 0.9902634024620056
#              test accuracy with jaccard: 0.98092120885849
#              test accuracy with dice: 0.9903335571289062
#              test accuracy with pixel by pixel: 0.9903645515441895
# Step 3474    training accuracy with jaccard: 0.9801520109176636
#              training accuracy with dice: 0.990092396736145
#              training accuracy with pixel by pixel: 0.9899027347564697
#              test accuracy with jaccard: 0.9807617664337158
#              test accuracy with dice: 0.9906396865844727
#              test accuracy with pixel by pixel: 0.9901049137115479
# Step 3492    training accuracy with jaccard: 0.981480062007904
#              training accuracy with dice: 0.9906711578369141
#              training accuracy with pixel by pixel: 0.9906888604164124
#              test accuracy with jaccard: 0.9799641370773315
#              test accuracy with dice: 0.9899170994758606
#              test accuracy with pixel by pixel: 0.989600658416748
# Step 3510    training accuracy with jaccard: 0.9812138080596924
#              training accuracy with dice: 0.9905664920806885
#              training accuracy with pixel by pixel: 0.9904552102088928
#              test accuracy with jaccard: 0.9784606695175171
#              test accuracy with dice: 0.9890053868293762
#              test accuracy with pixel by pixel: 0.9892438650131226
# Step 3528    training accuracy with jaccard: 0.9815653562545776
#              training accuracy with dice: 0.9907001852989197
#              training accuracy with pixel by pixel: 0.9907042980194092
#              test accuracy with jaccard: 0.9794331789016724
#              test accuracy with dice: 0.9897648692131042
#              test accuracy with pixel by pixel: 0.989478588104248
# Step 3546    training accuracy with jaccard: 0.9818032383918762
#              training accuracy with dice: 0.9908068180084229
#              training accuracy with pixel by pixel: 0.990727424621582
#              test accuracy with jaccard: 0.9793163537979126
#              test accuracy with dice: 0.9895772933959961
#              test accuracy with pixel by pixel: 0.9893141984939575
# Step 3564    training accuracy with jaccard: 0.9809446334838867
#              training accuracy with dice: 0.9904350638389587
#              training accuracy with pixel by pixel: 0.9902969002723694
#              test accuracy with jaccard: 0.9812315702438354
#              test accuracy with dice: 0.9905793070793152
#              test accuracy with pixel by pixel: 0.9905223846435547
# Step 3582    training accuracy with jaccard: 0.9815213680267334
#              training accuracy with dice: 0.9906565546989441
#              training accuracy with pixel by pixel: 0.9907000064849854
#              test accuracy with jaccard: 0.980885922908783
#              test accuracy with dice: 0.9903469085693359
#              test accuracy with pixel by pixel: 0.9904495477676392
# Step 3600    training accuracy with jaccard: 0.9807609915733337
#              training accuracy with dice: 0.9903202056884766
#              training accuracy with pixel by pixel: 0.9901565909385681
#              test accuracy with jaccard: 0.9795029759407043
#              test accuracy with dice: 0.9897937774658203
#              test accuracy with pixel by pixel: 0.9896237850189209
# Finished training.

# %%
val_acc_dice=[]
val_acc_jaccard=[]
val_acc_pixel=[]
val_loader = DataLoader(SOC_dataset_label, batch_size=BATCH_SIZE)

for inputs, targets in val_loader:
  inputs_val, targets = inputs.to(device), targets.to(device)

un_target=targets.unique()
# Compute loss.
targets[targets==un_target[0]]=0
targets[targets==un_target[1]]=1
targets[targets==un_target[2]]=2

targets_val=targets

# %%
max_size=inputs_val.size(3)
nr_images=int(max_size/128)

im=[]
tar=[]
for i in range(nr_images):
  im.append(inputs_val[:,:,((i)*128):((i+1)*128),((i)*128):((i+1)*128)])
  tar.append(targets_val[:,((i)*128):((i+1)*128),((i)*128):((i+1)*128)])

# %%
preds=[]

for i in range(nr_images):
  output_val = net(im[i])
  predicted_val = output_val.max(1)[1]

  val_acc_dice.append(dice(predicted_val,tar[i]))
  val_acc_jaccard.append(jaccard(predicted_val,tar[i]))
  val_acc_pixel.append(accuracy(predicted_val,tar[i]))

  output=output_val
  targets=tar[i] [0,:,:]
  predicted=predicted_val
  inputs=inputs_val

  fig,axs = plt.subplots(2,2,figsize=(15,15))
  im1=axs[0,0].imshow(output.detach().cpu().numpy()[0,0,:,:])
  axs[0,0].set_title('Label 1, probability')
  cbar1=plt.colorbar(im1, ax=axs[0,0])
  im1.set_clim(0,1)
  im2=axs[1,0].imshow(output.detach().cpu().numpy()[0,1,:,:])
  axs[1,0].set_title('Label 2, probability')
  plt.colorbar(im2, ax=axs[1,0])
  im2.set_clim(0,1)
  im3=axs[0,1].imshow(output.detach().cpu().numpy()[0,2,:,:])
  axs[0,1].set_title('Label 3,probabiliy')
  plt.colorbar(im3, ax=axs[0,1])
  im3.set_clim(0,1)
  im4=axs[1,1].imshow(targets.cpu())
  axs[1,1].set_title('Target labels')
  plt.colorbar(im4, ax=axs[1,1],ticks=[0,1,2])
  fig.suptitle('Probability distribution for each class', fontsize=16)

  plt.show()

  fig,axs=plt.subplots(2,2,figsize=(15,15))
  im1=axs[1,0].imshow(predicted[0,:,:].cpu())
  axs[1,0].set_title('Predicted labels')
  plt.colorbar(im1, ax=axs[1, 0],ticks=[0,1,2])
  im2=axs[1,1].imshow(targets.cpu())
  axs[1,1].set_title('Target labels')
  plt.colorbar(im2, ax=axs[1,1],ticks=[0,1,2])
  im3=axs[0,0].imshow(inputs[0,0,:,:].cpu())
  axs[0,0].set_title('Original image')
  plt.colorbar(im3, ax=axs[0,0])
  im4=axs[0,1].imshow(targets.cpu()-predicted[0,:,:].cpu())
  axs[0,1].set_title('Difference between mask and prediction')
  plt.colorbar(im4, ax=axs[0,1],ticks=[0,1,2])

  fig.suptitle('Comparison of target and predicted mask', fontsize=16)
  plt.show()

  preds.append(predicted)

# %%
#Combining the image
images=inputs_val.unfold(2, 128, 128).unfold(3, 128, 128)

plt.imshow(images[0,0,0,1,:,:].cpu().detach().numpy())

# %%
fig,axs=plt.subplots(1,2,figsize=(15,5))
axs[0].plot(train_accuracies_dice,color='red',label='dice')
axs[0].plot(train_accuracies_jaccard,color='blue',label='jaccard')
axs[0].plot(train_accuracies_pixel,color='green',label='pixel-wise')
axs[0].legend()
axs[0].set_title('Training accuracies')
axs[0].set_xlabel('Epoch number')
axs[0].set_ylabel('Accuracy)')

axs[1].plot(valid_accuracies_dice,color='red',label='dice')
axs[1].plot(valid_accuracies_jaccard,color='blue',label='jaccard')
axs[1].plot(valid_accuracies_pixel,color='green',label='pixel-wise')
axs[1].legend()
axs[1].set_title('Validation accuracies')
axs[1].set_xlabel('Epoch number')
axs[1].set_ylabel('Accuracy)')

fig,axs=plt.subplots(1,3,figsize=(15,5))
axs[0].plot(train_accuracies_dice,color='red',label='Training accuracy')
axs[0].plot(valid_accuracies_dice,color='blue',label='Validation accuracy')
axs[0].set_title('Dice coefficient accuracies')
axs[0].legend()

axs[1].plot(train_accuracies_jaccard,color='red',label='Training accuracy')
axs[1].plot(valid_accuracies_jaccard,color='blue',label='Validation accuracy')
axs[1].set_title('Jaccard coefficient accuracies')
axs[1].legend()

axs[2].plot(train_accuracies_pixel,color='red',label='Training accuracy')
axs[2].plot(valid_accuracies_pixel,color='blue',label='Validation accuracy')
axs[2].set_title('Pixelwise coefficient accuracies')
axs[2].legend()

# %%
from torchvision.utils import make_grid
inputs, targets = next(iter(test_loader))
inputs, targets = inputs.to(device), targets.to(device)

outputs = net(inputs)
_, predicted = torch.max(outputs.data, 1)

un_target=targets.unique()
# Compute loss.
targets[targets==un_target[0]]=0
targets[targets==un_target[1]]=1
targets[targets==un_target[2]]=2

targets = targets.to(torch.int64)

fig,axs = plt.subplots(1,3,figsize=(15,15))

axs[0].imshow(output.detach().cpu().numpy()[0,0,:,:])
axs[0].set_title('Label 1, probability')
axs[1].imshow(output.detach().cpu().numpy()[0,1,:,:])
axs[1].set_title('Label 2, probability')
axs[2].imshow(output.detach().cpu().numpy()[0,2,:,:])
axs[2].set_title('Label 3,probabiliy')
fig.suptitle('Probability distribution for each class', fontsize=16)
plt.show()

# %%
fig,axs=plt.subplots(2,2,figsize=(15,15))
im1=axs[1,0].imshow(predicted[0,:,:].cpu())
axs[1,0].set_title('Predicted labels')
plt.colorbar(im1, ax=axs[1, 0])
targets = targets.to(torch.int64) [0,:,:]
im2=axs[0,1].imshow(targets.cpu())
axs[0,1].set_title('Target labels')
plt.colorbar(im2, ax=axs[0,1])
im3=axs[0,0].imshow(inputs[0,0,:,:].cpu())
axs[0,0].set_title('Original image')
plt.colorbar(im3, ax=axs[0,0])
im4=axs[1,1].imshow(targets.cpu()-predicted[0,:,:].cpu())
axs[1,1].set_title('Difference between mask and prediction')
plt.colorbar(im4, ax=axs[1,1])

fig.suptitle('Comparison of target and predicted mask', fontsize=16)
plt.show()
