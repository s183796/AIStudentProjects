# %% [markdown]
# <a href="https://colab.research.google.com/github/s183796/AIStudentProjects/blob/christine/UNet_2d.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from typing import *
import matplotlib
import matplotlib.pyplot as plt
from IPython.display import Image, display, clear_output
import numpy as np
# %matplotlib nbagg
# %matplotlib inline
import seaborn as sns
import pandas as pd

import torch
import torch.nn as nn
from torchvision import models
from torch.nn.functional import relu
from torch.nn.functional import softmax
import PIL.Image
import os
import torchvision
import cv2

from torchvision import transforms
from sklearn.model_selection import train_test_split

from sklearn.metrics import accuracy_score
from torch.utils.data import DataLoader, Dataset, Subset

import torch.nn.functional as F
import torch.optim as optim
import torchvision.transforms.functional as TF
import glob

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
pip install albumentations
# Out:
# Requirement already satisfied: albumentations in /usr/local/lib/python3.10/dist-packages (1.3.1)
# Requirement already satisfied: numpy>=1.11.1 in /usr/local/lib/python3.10/dist-packages (from albumentations) (1.23.5)
# Requirement already satisfied: scipy>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from albumentations) (1.11.3)
# Requirement already satisfied: scikit-image>=0.16.1 in /usr/local/lib/python3.10/dist-packages (from albumentations) (0.19.3)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.10/dist-packages (from albumentations) (6.0.1)
# Requirement already satisfied: qudida>=0.0.4 in /usr/local/lib/python3.10/dist-packages (from albumentations) (0.0.4)
# Requirement already satisfied: opencv-python-headless>=4.1.1 in /usr/local/lib/python3.10/dist-packages (from albumentations) (4.8.1.78)
# Requirement already satisfied: scikit-learn>=0.19.1 in /usr/local/lib/python3.10/dist-packages (from qudida>=0.0.4->albumentations) (1.2.2)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from qudida>=0.0.4->albumentations) (4.5.0)
# Requirement already satisfied: networkx>=2.2 in /usr/local/lib/python3.10/dist-packages (from scikit-image>=0.16.1->albumentations) (3.2.1)
# Requirement already satisfied: pillow!=7.1.0,!=7.1.1,!=8.3.0,>=6.1.0 in /usr/local/lib/python3.10/dist-packages (from scikit-image>=0.16.1->albumentations) (9.4.0)
# Requirement already satisfied: imageio>=2.4.1 in /usr/local/lib/python3.10/dist-packages (from scikit-image>=0.16.1->albumentations) (2.31.6)
# Requirement already satisfied: tifffile>=2019.7.26 in /usr/local/lib/python3.10/dist-packages (from scikit-image>=0.16.1->albumentations) (2023.9.26)
# Requirement already satisfied: PyWavelets>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-image>=0.16.1->albumentations) (1.4.1)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from scikit-image>=0.16.1->albumentations) (23.2)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.19.1->qudida>=0.0.4->albumentations) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.19.1->qudida>=0.0.4->albumentations) (3.2.0)

# %%
import albumentations as A
from albumentations.pytorch import ToTensorV2

# %%
class UNet(nn.Module): #from https://towardsdatascience.com/cook-your-first-u-net-in-pytorch-b3297a844cf3
    def __init__(self, n_class):
        super().__init__()

        # Encoder
        # In the encoder, convolutional layers with the Conv2d function are used to extract features from the input image.
        # Each block in the encoder consists of two convolutional layers followed by a max-pooling layer, with the exception of the last block which does not include a max-pooling layer.
        # -------
        # input: 1x128x128
        self.e11 = nn.Conv2d(1, 64, kernel_size=3,padding=1)
        self.e12 = nn.Conv2d(64, 64, kernel_size=3,padding=1)
        self.pool1 = nn.MaxPool2d(kernel_size=2, stride=2) #64x64x64

        self.e21 = nn.Conv2d(64, 128, kernel_size=3,padding=1)
        self.e22 = nn.Conv2d(128, 128, kernel_size=3,padding=1)
        self.pool2 = nn.MaxPool2d(kernel_size=2, stride=2) #32x32x128

        self.e31 = nn.Conv2d(128, 256, kernel_size=3,padding=1)
        self.e32 = nn.Conv2d(256, 256, kernel_size=3,padding=1)

        self.pool3 = nn.MaxPool2d(kernel_size=2, stride=2) #16x16x256

        self.e41 = nn.Conv2d(256, 512, kernel_size=3,padding=1)
        self.e42 = nn.Conv2d(512, 512, kernel_size=3,padding=1)
        self.pool4 = nn.MaxPool2d(kernel_size=2, stride=2) #8x8x512

        self.e51 = nn.Conv2d(512, 1024, kernel_size=3,padding=1)
        self.e52 = nn.Conv2d(1024, 1024, kernel_size=3,padding=1)

        self.upconv1 = nn.ConvTranspose2d(1024,512,kernel_size=2,stride=2) #16x16x1024
        self.d11 = nn.Conv2d(1024,512,kernel_size=3,padding=1)
        self.d12 = nn.Conv2d(512,512,kernel_size=3,padding=1)

        self.upconv2 = nn.ConvTranspose2d(512,256,kernel_size=2,stride=2) #
        self.d21 = nn.Conv2d(512,256,kernel_size=3,padding=1)
        self.d22 = nn.Conv2d(256,256,kernel_size=3,padding=1)

        self.upconv3 = nn.ConvTranspose2d(256,128,kernel_size=2,stride=2)
        self.d31 = nn.Conv2d(128,128,kernel_size=3,padding=1)
        self.d32 = nn.Conv2d(128,128,kernel_size=3,padding=1)

        self.upconv4 = nn.ConvTranspose2d(128,64,kernel_size=2,stride=2)
        self.d41 = nn.Conv2d(64,64,kernel_size=3,padding=1)
        self.d42 = nn.Conv2d(64,64,kernel_size=3,padding=1)

        self.outconv = nn.Conv2d(64, n_class, kernel_size=1)

    def forward(self, x):
        # Encoder
        xe11 = F.relu(self.e11(x))
        xe12 = F.relu(self.e12(xe11))
        xp1 = self.pool1(xe12)

        xe21 = F.relu(self.e21(xp1))
        xe22 = F.relu(self.e22(xe21))
        xp2 = self.pool2(xe22)


        xe31 = F.relu(self.e31(xp2))
        xe32 = F.relu(self.e32(xe31))


        xp3 = self.pool3(xe32)

        xe41 = F.relu(self.e41(xp3))
        xe42 = F.relu(self.e42(xe41))
        xp4 = self.pool4(xe42)

        xe51 = F.relu(self.e51(xp4))
        xe52 = F.relu(self.e52(xe51))

        # Up-convolutions
        xup1 = self.upconv1(xe52)
        #xcat=xup1
        xcat = torch.cat([xup1, xe42], dim=1)

        xup21 = F.relu(self.d11(xcat))
        xup22 = F.relu(self.d12(xup21))

        xup2 = self.upconv2(xup22)
        #xcat2=xup2
        #xcat2 = torch.cat([xup2, xe32[:,:,:-1,:-1]], dim=1)
        xcat2 = torch.cat([xup2, xe32], dim=1)


        xup31 = F.relu(self.d21(xcat2))
        xup32 = F.relu(self.d22(xup31))
        xup3 = self.upconv3(xup32)
        xcat3=xup3
        #xcat3 = torch.cat([xup3, xe22], dim=1)

        xup41 = F.relu(self.d31(xcat3))
        xup42 = F.relu(self.d32(xup41))

        xup4 = self.upconv4(xup42)
        #xcat4 = torch.cat([xup4, xe12[:,:,2:-3,2:-3]], dim=1)
        #xcat4 = torch.cat([xup4, xe12], dim=1)
        xcat4=xup4
        xup51 = F.relu(self.d41(xcat4))
        xup52 = F.relu(self.d42(xup51))

        out = self.outconv(xup52)

        output = softmax(out,dim=1)

        return output

# %%
#Setting up hyper parameters, from exercise week 6


loss_fn =  nn.CrossEntropyLoss()         # <-- Your code here.

import random

# %%
class SOCDataset(Dataset):
    def __init__(self, root_dir, transform=None,transform_flip=None):
        self.root_dir = root_dir
        self.image_folder = os.path.join(root_dir, 'data/')
        self.label_folder = os.path.join(root_dir, 'labels/')
        self.transform = transform
        self.transform_flip = transform_flip

        self.image_filenames = sorted([f for f in os.listdir(self.image_folder) if f.endswith('.tiff')][:100])
        self.label_filenames = sorted([f for f in os.listdir(self.label_folder) if f.endswith('.tif')][:100])
    def _set_seed(self, seed):
        random.seed(seed)
        torch.manual_seed(seed)

    def __len__(self):
        return len(self.image_filenames)

    def __getitem__(self, idx):
      img_name = os.path.join(self.image_folder, self.image_filenames[idx])
      #label_name = os.path.join(self.label_folder, self.label_filenames[idx])
      #assert img_name[-8:-5] != label_name[-7:-4], f"Not corresponding label and image {img_name[-8:-5]}, {label_name[-7:-4]}"

      number1=img_name[-8:-5]
      label_name=os.path.join(self.label_folder,'slice__'+str(number1)+'.tif')

      image = cv2.imread(img_name, cv2.IMREAD_GRAYSCALE)
      label = cv2.imread(label_name, cv2.IMREAD_GRAYSCALE)

      image=np.array(image)
      label=np.array(label)

      if self.transform is not None:
        augmentations=self.transform(image=image,mask=label)

      image=augmentations["image"]
      label=augmentations["mask"]

      return image, label

# %%
transform = A.Compose(
    [
     #A.HorizontalFlip(p=0.5),
     A.RandomCrop(width=128, height=128),
     #A.VerticalFlip(p=0.1),
     #A.RandomBrightnessContrast(p=0.2),  # Adjust brightness/contrast
     #A.GaussNoise(p=0.2),  # Add Gaussian noise
     #A.Resize(64, 64, p=0.2),  # Downsample to 64x64
     #A.Resize(128, 128),  # Upsample back to 128x128
     A.Normalize(
        mean=[0.5],
        std=[0.5],
        max_pixel_value=255.0,
     ),
     ToTensorV2(),
    ]
)

# %%
SOC_dataset = SOCDataset(root_dir='drive/My Drive//AI data/', transform = transform)

# %%
image,label=SOC_dataset[33]

plt.figure(dpi=200)
plt.imshow(image[0,:,:])

plt.figure(dpi=200)
plt.imshow(label)

# %%
pip install torchmetrics
# Out:
# Requirement already satisfied: torchmetrics in /usr/local/lib/python3.10/dist-packages (1.2.0)
# Requirement already satisfied: numpy>1.20.0 in /usr/local/lib/python3.10/dist-packages (from torchmetrics) (1.23.5)
# Requirement already satisfied: torch>=1.8.1 in /usr/local/lib/python3.10/dist-packages (from torchmetrics) (2.1.0+cu118)
# Requirement already satisfied: lightning-utilities>=0.8.0 in /usr/local/lib/python3.10/dist-packages (from torchmetrics) (0.10.0)
# Requirement already satisfied: packaging>=17.1 in /usr/local/lib/python3.10/dist-packages (from lightning-utilities>=0.8.0->torchmetrics) (23.2)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from lightning-utilities>=0.8.0->torchmetrics) (67.7.2)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from lightning-utilities>=0.8.0->torchmetrics) (4.5.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.1->torchmetrics) (3.13.1)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.1->torchmetrics) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.1->torchmetrics) (3.2.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.1->torchmetrics) (3.1.2)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.1->torchmetrics) (2023.6.0)
# Requirement already satisfied: triton==2.1.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.1->torchmetrics) (2.1.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.8.1->torchmetrics) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.8.1->torchmetrics) (1.3.0)

# %%
from torchmetrics.classification import JaccardIndex

# %%
from sklearn.model_selection import train_test_split

TEST_SIZE = 0.3
BATCH_SIZE = 16
SEED = 42

# generate indices: instead of the actual data we pass in integers instead
train_indices, test_indices = train_test_split(
    range(len(SOC_dataset)),
    test_size=TEST_SIZE,
    random_state=SEED
)

val_indices, test_indices = train_test_split(
    test_indices,
    test_size=0.5,
    random_state=SEED
)

# generate subset based on indices
train_split = Subset(SOC_dataset, train_indices)
test_split = Subset(SOC_dataset, test_indices)
val_split = Subset(SOC_dataset, val_indices)

# create batches
train_loader = DataLoader(train_split, batch_size=BATCH_SIZE, shuffle=True)
test_loader = DataLoader(test_split, batch_size=BATCH_SIZE)
val_loader = DataLoader(val_split, batch_size=BATCH_SIZE)

# %%
net=UNet(n_class=3)

from torchmetrics.functional.classification import dice
from torchmetrics.classification import MulticlassAccuracy
#metric=Dice(num_classes=3)


optimizer = optim.Adam(net.parameters(), lr=0.0001)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
net.to(device)

jaccard=JaccardIndex(task="multiclass", num_classes=3).to(device)
accuracy=MulticlassAccuracy(num_classes=3).to(device)
batch_size = 16
num_epochs = 200 #changing the num_epochs from 2 to 12
validation_every_steps = np.ceil(len(train_loader.dataset)/batch_size)

step = 0
net.train()

train_accuracies_jaccard = []
train_accuracies_dice = []
train_accuracies_pixel = []
valid_accuracies_jaccard = []
valid_accuracies_dice = []
valid_accuracies_pixel = []

for epoch in range(num_epochs):
    train_accuracies_batches_jaccard = []
    train_accuracies_batches_dice = []
    train_accuracies_batches_pixel = []

    for inputs, targets in train_loader:
        inputs, targets = inputs.to(device), targets.to(device)


        # Forward pass, compute gradients, perform one training step.
        # Your code here!
        # Forward pass.
        output = net(inputs)

        un_target=targets.unique()
        # Compute loss.
        targets[targets==un_target[0]]=0
        targets[targets==un_target[1]]=1
        targets[targets==un_target[2]]=2

        targets = targets.to(torch.int64)

        loss = loss_fn(output, targets)

        # Clean up gradients from the model.
        optimizer.zero_grad()

        # Compute gradients based on the loss from the current batch (backpropagation).
        loss.backward()

        # Take one optimizer step using the gradients computed in the previous step.
        optimizer.step()

        # Increment step counter
        step += 1

        # Compute accuracy.
        predictions = torch.argmax(output,dim=1)
        train_accuracies_batches_dice.append(dice(predictions,targets).cpu())
        train_accuracies_batches_jaccard.append(jaccard(predictions,targets).cpu())
        train_accuracies_batches_pixel.append(accuracy(predictions,targets).cpu())

        if step % validation_every_steps == 0:

            # Append average training accuracy to list.
            train_accuracies_jaccard.append(np.mean(train_accuracies_batches_jaccard))
            train_accuracies_dice.append(np.mean(train_accuracies_batches_dice))
            train_accuracies_pixel.append(np.mean(train_accuracies_batches_pixel))

            train_accuracies_batches_jaccard = []
            train_accuracies_batches_dice = []
            train_accuracies_batches_pixel = []

            # Compute accuracies on validation set.
            valid_accuracies_batches_jaccard = []
            valid_accuracies_batches_dice = []
            valid_accuracies_batches_pixel = []
            with torch.no_grad():
                net.eval()
                for inputs, targets in test_loader:
                    inputs, targets = inputs.to(device), targets.to(device)
                    output = net(inputs)

                    un_target=targets.unique()
                    # Compute loss.
                    targets[targets==un_target[0]]=0
                    targets[targets==un_target[1]]=1
                    targets[targets==un_target[2]]=2

                    targets = targets.to(torch.int64)

                    loss = loss_fn(output, targets)

                    predictions = output.max(1)[1]
                    # Multiply by len(x) because the final batch of DataLoader may be smaller (drop_last=False).
                    valid_accuracies_batches_dice.append(dice(predictions,targets).cpu())
                    valid_accuracies_batches_jaccard.append(jaccard(predictions,targets).cpu())
                    valid_accuracies_batches_pixel.append(accuracy(predictions,targets).cpu())

                net.train()

            # Append average validation accuracy to list.
            valid_accuracies_jaccard.append(np.sum(valid_accuracies_batches_jaccard) / len(test_loader))
            valid_accuracies_dice.append(np.sum(valid_accuracies_batches_dice) / len(test_loader))
            valid_accuracies_pixel.append(np.sum(valid_accuracies_batches_pixel) / len(test_loader))

            print(f"Step {step:<5}   training accuracy with jaccard: {train_accuracies_jaccard[-1]}")
            print(f"             training accuracy with dice: {train_accuracies_dice[-1]}")
            print(f"             training accuracy with pixel by pixel: {train_accuracies_pixel[-1]}")
            print(f"             test accuracy with jaccard: {valid_accuracies_jaccard[-1]}")
            print(f"             test accuracy with dice: {valid_accuracies_dice[-1]}")
            print(f"             test accuracy with pixel by pixel: {valid_accuracies_pixel[-1]}")


print("Finished training.")
# Out:
# Step 5       training accuracy with jaccard: 0.09685541689395905
#              training accuracy with dice: 0.29056626558303833
#              training accuracy with pixel by pixel: 0.3333333432674408
#              test accuracy with jaccard: 0.09117025136947632
#              test accuracy with dice: 0.27351075410842896
#              test accuracy with pixel by pixel: 0.3333333432674408
# Step 10      training accuracy with jaccard: 0.09315219521522522
#              training accuracy with dice: 0.27945658564567566
#              training accuracy with pixel by pixel: 0.3333333432674408
#              test accuracy with jaccard: 0.08557400107383728
#              test accuracy with dice: 0.25672200322151184
#              test accuracy with pixel by pixel: 0.3333333432674408
# Step 15      training accuracy with jaccard: 0.09331884980201721
#              training accuracy with dice: 0.27995654940605164
#              training accuracy with pixel by pixel: 0.3333333432674408
#              test accuracy with jaccard: 0.1082492396235466
#              test accuracy with dice: 0.3247477114200592
#              test accuracy with pixel by pixel: 0.3333333432674408
# Step 20      training accuracy with jaccard: 0.13749611377716064
#              training accuracy with dice: 0.3680524230003357
#              training accuracy with pixel by pixel: 0.3329657316207886
#              test accuracy with jaccard: 0.15099366009235382
#              test accuracy with dice: 0.42741698026657104
#              test accuracy with pixel by pixel: 0.33156752586364746
# Step 25      training accuracy with jaccard: 0.1507386863231659
#              training accuracy with dice: 0.4424301087856293
#              training accuracy with pixel by pixel: 0.33318185806274414
#              test accuracy with jaccard: 0.13670358061790466
#              test accuracy with dice: 0.4098144471645355
#              test accuracy with pixel by pixel: 0.33337634801864624
# Step 30      training accuracy with jaccard: 0.14499251544475555
#              training accuracy with dice: 0.43484216928482056
#              training accuracy with pixel by pixel: 0.3333389461040497
#              test accuracy with jaccard: 0.15299615263938904
#              test accuracy with dice: 0.4589884579181671
#              test accuracy with pixel by pixel: 0.3333333432674408
# Step 35      training accuracy with jaccard: 0.14142803847789764
#              training accuracy with dice: 0.4242841303348541
#              training accuracy with pixel by pixel: 0.3333333432674408
#              test accuracy with jaccard: 0.13848605751991272
#              test accuracy with dice: 0.41545817255973816
#              test accuracy with pixel by pixel: 0.3333333432674408
# Step 40      training accuracy with jaccard: 0.14990726113319397
#              training accuracy with dice: 0.4497217535972595
#              training accuracy with pixel by pixel: 0.3333333432674408
#              test accuracy with jaccard: 0.1459282785654068
#              test accuracy with dice: 0.4377848207950592
#              test accuracy with pixel by pixel: 0.3333333432674408
# Step 45      training accuracy with jaccard: 0.13365690410137177
#              training accuracy with dice: 0.4009706974029541
#              training accuracy with pixel by pixel: 0.3333333432674408
#              test accuracy with jaccard: 0.13898111879825592
#              test accuracy with dice: 0.41694337129592896
#              test accuracy with pixel by pixel: 0.3333333432674408
# Step 50      training accuracy with jaccard: 0.14070579409599304
#              training accuracy with dice: 0.4221173822879791
#              training accuracy with pixel by pixel: 0.3333333432674408
#              test accuracy with jaccard: 0.12614475190639496
#              test accuracy with dice: 0.3784342408180237
#              test accuracy with pixel by pixel: 0.3333333432674408
# Step 55      training accuracy with jaccard: 0.14005662500858307
#              training accuracy with dice: 0.4201698303222656
#              training accuracy with pixel by pixel: 0.3333333432674408
#              test accuracy with jaccard: 0.11275363713502884
#              test accuracy with dice: 0.3382609188556671
#              test accuracy with pixel by pixel: 0.3333333432674408
# Step 60      training accuracy with jaccard: 0.13355466723442078
#              training accuracy with dice: 0.40066322684288025
#              training accuracy with pixel by pixel: 0.3333333432674408
#              test accuracy with jaccard: 0.14613749086856842
#              test accuracy with dice: 0.4383504092693329
#              test accuracy with pixel by pixel: 0.33335041999816895
# Step 65      training accuracy with jaccard: 0.13870257139205933
#              training accuracy with dice: 0.41593116521835327
#              training accuracy with pixel by pixel: 0.3333815634250641
#              test accuracy with jaccard: 0.13685712218284607
#              test accuracy with dice: 0.4102742373943329
#              test accuracy with pixel by pixel: 0.33341190218925476
# Step 70      training accuracy with jaccard: 0.2060522735118866
#              training accuracy with dice: 0.4962374269962311
#              training accuracy with pixel by pixel: 0.3811010420322418
#              test accuracy with jaccard: 0.3547554612159729
#              test accuracy with dice: 0.6142618656158447
#              test accuracy with pixel by pixel: 0.5476673245429993
# Step 75      training accuracy with jaccard: 0.4081593453884125
#              training accuracy with dice: 0.6567769646644592
#              training accuracy with pixel by pixel: 0.593184232711792
#              test accuracy with jaccard: 0.4179595112800598
#              test accuracy with dice: 0.6705159544944763
#              test accuracy with pixel by pixel: 0.6022466421127319
# Step 80      training accuracy with jaccard: 0.46357837319374084
#              training accuracy with dice: 0.6819869875907898
#              training accuracy with pixel by pixel: 0.6338436007499695
#              test accuracy with jaccard: 0.4519708752632141
#              test accuracy with dice: 0.6471720337867737
#              test accuracy with pixel by pixel: 0.6266995668411255
# Step 85      training accuracy with jaccard: 0.4610258936882019
#              training accuracy with dice: 0.6949905157089233
#              training accuracy with pixel by pixel: 0.6289952993392944
#              test accuracy with jaccard: 0.4588279724121094
#              test accuracy with dice: 0.720202624797821
#              test accuracy with pixel by pixel: 0.6308757066726685
# Step 90      training accuracy with jaccard: 0.4406886100769043
#              training accuracy with dice: 0.6612922549247742
#              training accuracy with pixel by pixel: 0.6333600282669067
#              test accuracy with jaccard: 0.436257928609848
#              test accuracy with dice: 0.6748697757720947
#              test accuracy with pixel by pixel: 0.6373077630996704
# Step 95      training accuracy with jaccard: 0.44669872522354126
#              training accuracy with dice: 0.6969957947731018
#              training accuracy with pixel by pixel: 0.6339744329452515
#              test accuracy with jaccard: 0.44139423966407776
#              test accuracy with dice: 0.6772786378860474
#              test accuracy with pixel by pixel: 0.6316255927085876
# Step 100     training accuracy with jaccard: 0.44081583619117737
#              training accuracy with dice: 0.6713297367095947
#              training accuracy with pixel by pixel: 0.6358330845832825
#              test accuracy with jaccard: 0.45636624097824097
#              test accuracy with dice: 0.6804606318473816
#              test accuracy with pixel by pixel: 0.6440094709396362
# Step 105     training accuracy with jaccard: 0.4478737711906433
#              training accuracy with dice: 0.6790122985839844
#              training accuracy with pixel by pixel: 0.638158917427063
#              test accuracy with jaccard: 0.46114954352378845
#              test accuracy with dice: 0.6906901001930237
#              test accuracy with pixel by pixel: 0.6397733688354492
# Step 110     training accuracy with jaccard: 0.46292394399642944
#              training accuracy with dice: 0.6888918280601501
#              training accuracy with pixel by pixel: 0.6413031816482544
#              test accuracy with jaccard: 0.4800378084182739
#              test accuracy with dice: 0.7020100951194763
#              test accuracy with pixel by pixel: 0.6497818231582642
# Step 115     training accuracy with jaccard: 0.4704109728336334
#              training accuracy with dice: 0.6791394948959351
#              training accuracy with pixel by pixel: 0.6512259244918823
#              test accuracy with jaccard: 0.46170032024383545
#              test accuracy with dice: 0.6690266728401184
#              test accuracy with pixel by pixel: 0.6585836410522461
# Step 120     training accuracy with jaccard: 0.5027979612350464
#              training accuracy with dice: 0.727190375328064
#              training accuracy with pixel by pixel: 0.6682819128036499
#              test accuracy with jaccard: 0.4954248070716858
#              test accuracy with dice: 0.6903971433639526
#              test accuracy with pixel by pixel: 0.6848751902580261
# Step 125     training accuracy with jaccard: 0.5413950681686401
#              training accuracy with dice: 0.7507436275482178
#              training accuracy with pixel by pixel: 0.7081536054611206
#              test accuracy with jaccard: 0.5764926671981812
#              test accuracy with dice: 0.758129894733429
#              test accuracy with pixel by pixel: 0.7361960411071777
# Step 130     training accuracy with jaccard: 0.5524654388427734
#              training accuracy with dice: 0.7585967779159546
#              training accuracy with pixel by pixel: 0.7095731496810913
#              test accuracy with jaccard: 0.55134117603302
#              test accuracy with dice: 0.7543253302574158
#              test accuracy with pixel by pixel: 0.7098634243011475
# Step 135     training accuracy with jaccard: 0.5421326160430908
#              training accuracy with dice: 0.7547277212142944
#              training accuracy with pixel by pixel: 0.7091274261474609
#              test accuracy with jaccard: 0.6853624582290649
#              test accuracy with dice: 0.832836925983429
#              test accuracy with pixel by pixel: 0.8141177892684937
# Step 140     training accuracy with jaccard: 0.6014038920402527
#              training accuracy with dice: 0.7891194820404053
#              training accuracy with pixel by pixel: 0.7464137077331543
#              test accuracy with jaccard: 0.5421181917190552
#              test accuracy with dice: 0.7254801392555237
#              test accuracy with pixel by pixel: 0.7130393981933594
# Step 145     training accuracy with jaccard: 0.636137843132019
#              training accuracy with dice: 0.8009956479072571
#              training accuracy with pixel by pixel: 0.7720969319343567
#              test accuracy with jaccard: 0.7338275909423828
#              test accuracy with dice: 0.8585245609283447
#              test accuracy with pixel by pixel: 0.8438434600830078
# Step 150     training accuracy with jaccard: 0.6915732622146606
#              training accuracy with dice: 0.8391769528388977
#              training accuracy with pixel by pixel: 0.8134052157402039
#              test accuracy with jaccard: 0.6802374124526978
#              test accuracy with dice: 0.8511596918106079
#              test accuracy with pixel by pixel: 0.7915775775909424
# Step 155     training accuracy with jaccard: 0.7097429037094116
#              training accuracy with dice: 0.8494976758956909
#              training accuracy with pixel by pixel: 0.8264349102973938
#              test accuracy with jaccard: 0.7694917917251587
#              test accuracy with dice: 0.8887491822242737
#              test accuracy with pixel by pixel: 0.8648220300674438
# Step 160     training accuracy with jaccard: 0.7333758473396301
#              training accuracy with dice: 0.8650668263435364
#              training accuracy with pixel by pixel: 0.8440238833427429
#              test accuracy with jaccard: 0.796464741230011
#              test accuracy with dice: 0.9054483771324158
#              test accuracy with pixel by pixel: 0.8668646812438965
# Step 165     training accuracy with jaccard: 0.7793825268745422
#              training accuracy with dice: 0.89007568359375
#              training accuracy with pixel by pixel: 0.8731505274772644
#              test accuracy with jaccard: 0.8055434226989746
#              test accuracy with dice: 0.8967977166175842
#              test accuracy with pixel by pixel: 0.891433835029602
# Step 170     training accuracy with jaccard: 0.799205482006073
#              training accuracy with dice: 0.8989863395690918
#              training accuracy with pixel by pixel: 0.8860657811164856
#              test accuracy with jaccard: 0.7741763591766357
#              test accuracy with dice: 0.8720621466636658
#              test accuracy with pixel by pixel: 0.8808435201644897
# Step 175     training accuracy with jaccard: 0.8090952038764954
#              training accuracy with dice: 0.9054247736930847
#              training accuracy with pixel by pixel: 0.8910436630249023
#              test accuracy with jaccard: 0.865074098110199
#              test accuracy with dice: 0.93463134765625
#              test accuracy with pixel by pixel: 0.9228782057762146
# Step 180     training accuracy with jaccard: 0.8178380727767944
#              training accuracy with dice: 0.9073001146316528
#              training accuracy with pixel by pixel: 0.8960111737251282
#              test accuracy with jaccard: 0.8271194696426392
#              test accuracy with dice: 0.9095093011856079
#              test accuracy with pixel by pixel: 0.9049340486526489
# Step 185     training accuracy with jaccard: 0.8499008417129517
#              training accuracy with dice: 0.923939049243927
#              training accuracy with pixel by pixel: 0.916019082069397
#              test accuracy with jaccard: 0.8549580574035645
#              test accuracy with dice: 0.9271768927574158
#              test accuracy with pixel by pixel: 0.9174962043762207
# Step 190     training accuracy with jaccard: 0.8691022992134094
#              training accuracy with dice: 0.9326990842819214
#              training accuracy with pixel by pixel: 0.9288030862808228
#              test accuracy with jaccard: 0.8449481725692749
#              test accuracy with dice: 0.9214395880699158
#              test accuracy with pixel by pixel: 0.9142770767211914
# Step 195     training accuracy with jaccard: 0.887658953666687
#              training accuracy with dice: 0.9429583549499512
#              training accuracy with pixel by pixel: 0.9388254880905151
#              test accuracy with jaccard: 0.8938398361206055
#              test accuracy with dice: 0.9451741576194763
#              test accuracy with pixel by pixel: 0.943026065826416
# Step 200     training accuracy with jaccard: 0.8943809270858765
#              training accuracy with dice: 0.9470965266227722
#              training accuracy with pixel by pixel: 0.9424657821655273
#              test accuracy with jaccard: 0.8779870271682739
#              test accuracy with dice: 0.9362467527389526
#              test accuracy with pixel by pixel: 0.9374369382858276
# Step 205     training accuracy with jaccard: 0.8927599191665649
#              training accuracy with dice: 0.9464777708053589
#              training accuracy with pixel by pixel: 0.9439245462417603
#              test accuracy with jaccard: 0.9139607548713684
#              test accuracy with dice: 0.9561727046966553
#              test accuracy with pixel by pixel: 0.954494833946228
# Step 210     training accuracy with jaccard: 0.9067276120185852
#              training accuracy with dice: 0.9523060917854309
#              training accuracy with pixel by pixel: 0.949832558631897
#              test accuracy with jaccard: 0.8912557363510132
#              test accuracy with dice: 0.9432373046875
#              test accuracy with pixel by pixel: 0.946657657623291
# Step 215     training accuracy with jaccard: 0.8980571031570435
#              training accuracy with dice: 0.9480900764465332
#              training accuracy with pixel by pixel: 0.9429421424865723
#              test accuracy with jaccard: 0.9019373655319214
#              test accuracy with dice: 0.9482462406158447
#              test accuracy with pixel by pixel: 0.9515810012817383
# Step 220     training accuracy with jaccard: 0.9130163192749023
#              training accuracy with dice: 0.9557415843009949
#              training accuracy with pixel by pixel: 0.9533889889717102
#              test accuracy with jaccard: 0.9226130247116089
#              test accuracy with dice: 0.9621337652206421
#              test accuracy with pixel by pixel: 0.9623149633407593
# Step 225     training accuracy with jaccard: 0.915318489074707
#              training accuracy with dice: 0.9567001461982727
#              training accuracy with pixel by pixel: 0.9565658569335938
#              test accuracy with jaccard: 0.9198415279388428
#              test accuracy with dice: 0.9589070677757263
#              test accuracy with pixel by pixel: 0.95958411693573
# Step 230     training accuracy with jaccard: 0.9228045344352722
#              training accuracy with dice: 0.961292564868927
#              training accuracy with pixel by pixel: 0.9596158862113953
#              test accuracy with jaccard: 0.9322404861450195
#              test accuracy with dice: 0.9663940668106079
#              test accuracy with pixel by pixel: 0.9647948741912842
# Step 235     training accuracy with jaccard: 0.9265772104263306
#              training accuracy with dice: 0.963471531867981
#              training accuracy with pixel by pixel: 0.9621240496635437
#              test accuracy with jaccard: 0.9281345009803772
#              test accuracy with dice: 0.9629353880882263
#              test accuracy with pixel by pixel: 0.9628252983093262
# Step 240     training accuracy with jaccard: 0.9294551014900208
#              training accuracy with dice: 0.9645317196846008
#              training accuracy with pixel by pixel: 0.9636147618293762
#              test accuracy with jaccard: 0.9378591775894165
#              test accuracy with dice: 0.9681599736213684
#              test accuracy with pixel by pixel: 0.9678636789321899
# Step 245     training accuracy with jaccard: 0.9331669807434082
#              training accuracy with dice: 0.9659823179244995
#              training accuracy with pixel by pixel: 0.964921772480011
#              test accuracy with jaccard: 0.943195104598999
#              test accuracy with dice: 0.9719035029411316
#              test accuracy with pixel by pixel: 0.9699037075042725
# Step 250     training accuracy with jaccard: 0.9330524206161499
#              training accuracy with dice: 0.9661857485771179
#              training accuracy with pixel by pixel: 0.9654916524887085
#              test accuracy with jaccard: 0.9358376264572144
#              test accuracy with dice: 0.9688395261764526
#              test accuracy with pixel by pixel: 0.9658932685852051
# Step 255     training accuracy with jaccard: 0.935896098613739
#              training accuracy with dice: 0.9685931205749512
#              training accuracy with pixel by pixel: 0.9676934480667114
#              test accuracy with jaccard: 0.9354649782180786
#              test accuracy with dice: 0.9664469361305237
#              test accuracy with pixel by pixel: 0.9665840864181519
# Step 260     training accuracy with jaccard: 0.9165145754814148
#              training accuracy with dice: 0.9581738710403442
#              training accuracy with pixel by pixel: 0.957563579082489
#              test accuracy with jaccard: 0.9082362651824951
#              test accuracy with dice: 0.9547485113143921
#              test accuracy with pixel by pixel: 0.9552243947982788
# Step 265     training accuracy with jaccard: 0.908872127532959
#              training accuracy with dice: 0.954365074634552
#              training accuracy with pixel by pixel: 0.9533289074897766
#              test accuracy with jaccard: 0.9053994417190552
#              test accuracy with dice: 0.9498983025550842
#              test accuracy with pixel by pixel: 0.9483199119567871
# Step 270     training accuracy with jaccard: 0.9140657186508179
#              training accuracy with dice: 0.9561123847961426
#              training accuracy with pixel by pixel: 0.9544218182563782
#              test accuracy with jaccard: 0.9230610728263855
#              test accuracy with dice: 0.9605062007904053
#              test accuracy with pixel by pixel: 0.9581917524337769
# Step 275     training accuracy with jaccard: 0.9231789708137512
#              training accuracy with dice: 0.9606376886367798
#              training accuracy with pixel by pixel: 0.9579752087593079
#              test accuracy with jaccard: 0.9256409406661987
#              test accuracy with dice: 0.9617106318473816
#              test accuracy with pixel by pixel: 0.9630914926528931
# Step 280     training accuracy with jaccard: 0.9240649938583374
#              training accuracy with dice: 0.9622387886047363
#              training accuracy with pixel by pixel: 0.9593725204467773
#              test accuracy with jaccard: 0.9261840581893921
#              test accuracy with dice: 0.9636637568473816
#              test accuracy with pixel by pixel: 0.9623512029647827
# Step 285     training accuracy with jaccard: 0.929741382598877
#              training accuracy with dice: 0.9641072154045105
#              training accuracy with pixel by pixel: 0.9644951820373535
#              test accuracy with jaccard: 0.9287532567977905
#              test accuracy with dice: 0.9631998538970947
#              test accuracy with pixel by pixel: 0.9619282484054565
# Step 290     training accuracy with jaccard: 0.9362634420394897
#              training accuracy with dice: 0.9677349925041199
#              training accuracy with pixel by pixel: 0.9666765928268433
#              test accuracy with jaccard: 0.9457077980041504
#              test accuracy with dice: 0.9727091193199158
#              test accuracy with pixel by pixel: 0.9725686311721802
# Step 295     training accuracy with jaccard: 0.9370713233947754
#              training accuracy with dice: 0.9681953191757202
#              training accuracy with pixel by pixel: 0.9674379229545593
#              test accuracy with jaccard: 0.9335299730300903
#              test accuracy with dice: 0.9658650755882263
#              test accuracy with pixel by pixel: 0.9659502506256104
# Step 300     training accuracy with jaccard: 0.9392601251602173
#              training accuracy with dice: 0.9694081544876099
#              training accuracy with pixel by pixel: 0.9688919186592102
#              test accuracy with jaccard: 0.9431302547454834
#              test accuracy with dice: 0.9706583619117737
#              test accuracy with pixel by pixel: 0.9705151319503784
# Step 305     training accuracy with jaccard: 0.9399499893188477
#              training accuracy with dice: 0.9699310064315796
#              training accuracy with pixel by pixel: 0.9696550369262695
#              test accuracy with jaccard: 0.9418530464172363
#              test accuracy with dice: 0.9717447757720947
#              test accuracy with pixel by pixel: 0.9706771373748779
# Step 310     training accuracy with jaccard: 0.9384014010429382
#              training accuracy with dice: 0.9693008661270142
#              training accuracy with pixel by pixel: 0.9685840606689453
#              test accuracy with jaccard: 0.9418878555297852
#              test accuracy with dice: 0.9722086787223816
#              test accuracy with pixel by pixel: 0.9703227281570435
# Step 315     training accuracy with jaccard: 0.9423290491104126
#              training accuracy with dice: 0.9708244204521179
#              training accuracy with pixel by pixel: 0.9704359173774719
#              test accuracy with jaccard: 0.940656304359436
#              test accuracy with dice: 0.9694742560386658
#              test accuracy with pixel by pixel: 0.9698853492736816
# Step 320     training accuracy with jaccard: 0.946128249168396
#              training accuracy with dice: 0.9725097417831421
#              training accuracy with pixel by pixel: 0.9722031354904175
#              test accuracy with jaccard: 0.9430426359176636
#              test accuracy with dice: 0.9712809324264526
#              test accuracy with pixel by pixel: 0.9711461067199707
# Step 325     training accuracy with jaccard: 0.9420601725578308
#              training accuracy with dice: 0.9721089601516724
#              training accuracy with pixel by pixel: 0.9705110788345337
#              test accuracy with jaccard: 0.945235013961792
#              test accuracy with dice: 0.9730468988418579
#              test accuracy with pixel by pixel: 0.9735825657844543
# Step 330     training accuracy with jaccard: 0.94471675157547
#              training accuracy with dice: 0.971747875213623
#              training accuracy with pixel by pixel: 0.971467137336731
#              test accuracy with jaccard: 0.9380637407302856
#              test accuracy with dice: 0.9686442017555237
#              test accuracy with pixel by pixel: 0.9694124460220337
# Step 335     training accuracy with jaccard: 0.9423639178276062
#              training accuracy with dice: 0.9705861210823059
#              training accuracy with pixel by pixel: 0.9703925848007202
#              test accuracy with jaccard: 0.9399738907814026
#              test accuracy with dice: 0.9701293706893921
#              test accuracy with pixel by pixel: 0.9707037806510925
# Step 340     training accuracy with jaccard: 0.9465810060501099
#              training accuracy with dice: 0.9735768437385559
#              training accuracy with pixel by pixel: 0.9728549122810364
#              test accuracy with jaccard: 0.944720983505249
#              test accuracy with dice: 0.9720866084098816
#              test accuracy with pixel by pixel: 0.9732018709182739
# Step 345     training accuracy with jaccard: 0.9482458233833313
#              training accuracy with dice: 0.974127471446991
#              training accuracy with pixel by pixel: 0.9735203981399536
#              test accuracy with jaccard: 0.9442445039749146
#              test accuracy with dice: 0.971264660358429
#              test accuracy with pixel by pixel: 0.9717987179756165
# Step 350     training accuracy with jaccard: 0.9495528936386108
#              training accuracy with dice: 0.9745758175849915
#              training accuracy with pixel by pixel: 0.9745879173278809
#              test accuracy with jaccard: 0.9406777620315552
#              test accuracy with dice: 0.9701375365257263
#              test accuracy with pixel by pixel: 0.969732403755188
# Step 355     training accuracy with jaccard: 0.9473322629928589
#              training accuracy with dice: 0.9736224412918091
#              training accuracy with pixel by pixel: 0.9732652902603149
#              test accuracy with jaccard: 0.9499280452728271
#              test accuracy with dice: 0.9750894904136658
#              test accuracy with pixel by pixel: 0.9752299785614014
# Step 360     training accuracy with jaccard: 0.9511995315551758
#              training accuracy with dice: 0.975439190864563
#              training accuracy with pixel by pixel: 0.9750329852104187
#              test accuracy with jaccard: 0.9457287192344666
#              test accuracy with dice: 0.9728678464889526
#              test accuracy with pixel by pixel: 0.9721229076385498
# Step 365     training accuracy with jaccard: 0.9510356187820435
#              training accuracy with dice: 0.9758750796318054
#              training accuracy with pixel by pixel: 0.9752780795097351
#              test accuracy with jaccard: 0.9425400495529175
#              test accuracy with dice: 0.970812976360321
#              test accuracy with pixel by pixel: 0.9697953462600708
# Step 370     training accuracy with jaccard: 0.9515435099601746
#              training accuracy with dice: 0.9755078554153442
#              training accuracy with pixel by pixel: 0.9751216173171997
#              test accuracy with jaccard: 0.9477548599243164
#              test accuracy with dice: 0.9738851189613342
#              test accuracy with pixel by pixel: 0.97393798828125
# Step 375     training accuracy with jaccard: 0.9489791989326477
#              training accuracy with dice: 0.9743934869766235
#              training accuracy with pixel by pixel: 0.9741643071174622
#              test accuracy with jaccard: 0.9540805220603943
#              test accuracy with dice: 0.9777587652206421
#              test accuracy with pixel by pixel: 0.9766967296600342
# Step 380     training accuracy with jaccard: 0.9511207342147827
#              training accuracy with dice: 0.9757133722305298
#              training accuracy with pixel by pixel: 0.9750727415084839
#              test accuracy with jaccard: 0.9506133794784546
#              test accuracy with dice: 0.9752522706985474
#              test accuracy with pixel by pixel: 0.9743555784225464
# Step 385     training accuracy with jaccard: 0.9517570734024048
#              training accuracy with dice: 0.9754796028137207
#              training accuracy with pixel by pixel: 0.9755199551582336
#              test accuracy with jaccard: 0.9508830308914185
#              test accuracy with dice: 0.9753255248069763
#              test accuracy with pixel by pixel: 0.9753602743148804
# Step 390     training accuracy with jaccard: 0.9533084034919739
#              training accuracy with dice: 0.9769070744514465
#              training accuracy with pixel by pixel: 0.9760655164718628
#              test accuracy with jaccard: 0.9487365484237671
#              test accuracy with dice: 0.9745320677757263
#              test accuracy with pixel by pixel: 0.9747894406318665
# Step 395     training accuracy with jaccard: 0.952816367149353
#              training accuracy with dice: 0.9761635065078735
#              training accuracy with pixel by pixel: 0.9758365750312805
#              test accuracy with jaccard: 0.9478044509887695
#              test accuracy with dice: 0.9732869267463684
#              test accuracy with pixel by pixel: 0.9743118286132812
# Step 400     training accuracy with jaccard: 0.9540553092956543
#              training accuracy with dice: 0.9771151542663574
#              training accuracy with pixel by pixel: 0.977028489112854
#              test accuracy with jaccard: 0.9534004926681519
#              test accuracy with dice: 0.976147472858429
#              test accuracy with pixel by pixel: 0.9764388799667358
# Step 405     training accuracy with jaccard: 0.9534419775009155
#              training accuracy with dice: 0.976844310760498
#              training accuracy with pixel by pixel: 0.9761381149291992
#              test accuracy with jaccard: 0.9455080032348633
#              test accuracy with dice: 0.9720458984375
#              test accuracy with pixel by pixel: 0.970492959022522
# Step 410     training accuracy with jaccard: 0.9523550271987915
#              training accuracy with dice: 0.9763107299804688
#              training accuracy with pixel by pixel: 0.9758750796318054
#              test accuracy with jaccard: 0.9493571519851685
#              test accuracy with dice: 0.974291980266571
#              test accuracy with pixel by pixel: 0.9749533534049988
# Step 415     training accuracy with jaccard: 0.9513978958129883
#              training accuracy with dice: 0.975749671459198
#              training accuracy with pixel by pixel: 0.9756662249565125
#              test accuracy with jaccard: 0.9462164640426636
#              test accuracy with dice: 0.9734537601470947
#              test accuracy with pixel by pixel: 0.9698501825332642
# Step 420     training accuracy with jaccard: 0.9500543475151062
#              training accuracy with dice: 0.9749638438224792
#              training accuracy with pixel by pixel: 0.9748862981796265
#              test accuracy with jaccard: 0.95387864112854
#              test accuracy with dice: 0.9767211675643921
#              test accuracy with pixel by pixel: 0.9750259518623352
# Step 425     training accuracy with jaccard: 0.9504603147506714
#              training accuracy with dice: 0.975659966468811
#              training accuracy with pixel by pixel: 0.9743543863296509
#              test accuracy with jaccard: 0.9515988826751709
#              test accuracy with dice: 0.9759114384651184
#              test accuracy with pixel by pixel: 0.9761279821395874
# Step 430     training accuracy with jaccard: 0.9510937929153442
#              training accuracy with dice: 0.9751693606376648
#              training accuracy with pixel by pixel: 0.9747458696365356
#              test accuracy with jaccard: 0.9464266300201416
#              test accuracy with dice: 0.9723551273345947
#              test accuracy with pixel by pixel: 0.9728835821151733
# Step 435     training accuracy with jaccard: 0.9497893452644348
#              training accuracy with dice: 0.974744439125061
#              training accuracy with pixel by pixel: 0.9749025106430054
#              test accuracy with jaccard: 0.9565796256065369
#              test accuracy with dice: 0.9781656861305237
#              test accuracy with pixel by pixel: 0.9783003330230713
# Step 440     training accuracy with jaccard: 0.9557734727859497
#              training accuracy with dice: 0.9777989387512207
#              training accuracy with pixel by pixel: 0.9775915145874023
#              test accuracy with jaccard: 0.9562597274780273
#              test accuracy with dice: 0.9778767824172974
#              test accuracy with pixel by pixel: 0.9773285388946533
# Step 445     training accuracy with jaccard: 0.9549878239631653
#              training accuracy with dice: 0.9775962829589844
#              training accuracy with pixel by pixel: 0.9772821664810181
#              test accuracy with jaccard: 0.9493131637573242
#              test accuracy with dice: 0.9748575687408447
#              test accuracy with pixel by pixel: 0.9750626087188721
# Step 450     training accuracy with jaccard: 0.9525810480117798
#              training accuracy with dice: 0.9761418104171753
#              training accuracy with pixel by pixel: 0.9759175181388855
#              test accuracy with jaccard: 0.9584136605262756
#              test accuracy with dice: 0.979357898235321
#              test accuracy with pixel by pixel: 0.979604959487915
# Step 455     training accuracy with jaccard: 0.9538763761520386
#              training accuracy with dice: 0.9771350026130676
#              training accuracy with pixel by pixel: 0.9766475558280945
#              test accuracy with jaccard: 0.9596540927886963
#              test accuracy with dice: 0.9801838994026184
#              test accuracy with pixel by pixel: 0.9793846607208252
# Step 460     training accuracy with jaccard: 0.9596664309501648
#              training accuracy with dice: 0.9800616502761841
#              training accuracy with pixel by pixel: 0.9796042442321777
#              test accuracy with jaccard: 0.9520779848098755
#              test accuracy with dice: 0.976367175579071
#              test accuracy with pixel by pixel: 0.9733255505561829
# Step 465     training accuracy with jaccard: 0.9554578065872192
#              training accuracy with dice: 0.9776393175125122
#              training accuracy with pixel by pixel: 0.9770973324775696
#              test accuracy with jaccard: 0.9546101093292236
#              test accuracy with dice: 0.977160632610321
#              test accuracy with pixel by pixel: 0.9773236513137817
# Step 470     training accuracy with jaccard: 0.9564250707626343
#              training accuracy with dice: 0.9783244132995605
#              training accuracy with pixel by pixel: 0.9780689477920532
#              test accuracy with jaccard: 0.9563567638397217
#              test accuracy with dice: 0.9778686761856079
#              test accuracy with pixel by pixel: 0.9778791069984436

# %%
val_acc_dice=[]
val_acc_jaccard=[]
val_acc_pixel=[]

for inputs, targets in val_loader:
  inputs_val, targets = inputs.to(device), targets.to(device)

un_target=targets.unique()
# Compute loss.
targets[targets==un_target[0]]=0
targets[targets==un_target[1]]=1
targets[targets==un_target[2]]=2

targets_val=targets

# %%
output_val = net(inputs_val)
predicted_val = output_val.max(1)[1]

val_acc_dice.append(dice(predicted_val,targets))
val_acc_jaccard.append(jaccard(predicted_val,targets))
val_acc_pixel.append(accuracy(predicted_val,targets))

output=output_val
targets=targets_val [0,:,:]
predicted=predicted_val
inputs=inputs_val

fig,axs = plt.subplots(2,2,figsize=(15,15))
im1=axs[0,0].imshow(output.detach().cpu().numpy()[0,0,:,:])
axs[0,0].set_title('Label 1, probability')
cbar1=plt.colorbar(im1, ax=axs[0,0])
im1.set_clim(0,1)
im2=axs[1,0].imshow(output.detach().cpu().numpy()[0,1,:,:])
axs[1,0].set_title('Label 2, probability')
plt.colorbar(im2, ax=axs[1,0])
im2.set_clim(0,1)
im3=axs[0,1].imshow(output.detach().cpu().numpy()[0,2,:,:])
axs[0,1].set_title('Label 3,probabiliy')
plt.colorbar(im3, ax=axs[0,1])
im3.set_clim(0,1)
im4=axs[1,1].imshow(targets.cpu())
axs[1,1].set_title('Target labels')
plt.colorbar(im4, ax=axs[1,1],ticks=[0,1,2])
fig.suptitle('Probability distribution for each class', fontsize=16)

plt.show()

fig,axs=plt.subplots(2,2,figsize=(15,15))
im1=axs[1,0].imshow(predicted[0,:,:].cpu())
axs[1,0].set_title('Predicted labels')
plt.colorbar(im1, ax=axs[1, 0],ticks=[0,1,2])
im2=axs[1,1].imshow(targets.cpu())
axs[1,1].set_title('Target labels')
plt.colorbar(im2, ax=axs[1,1],ticks=[0,1,2])
im3=axs[0,0].imshow(inputs[0,0,:,:].cpu())
axs[0,0].set_title('Original image')
plt.colorbar(im3, ax=axs[0,0])
im4=axs[0,1].imshow(targets.cpu()-predicted[0,:,:].cpu())
axs[0,1].set_title('Difference between mask and prediction')
plt.colorbar(im4, ax=axs[0,1],ticks=[0,1,2])

fig.suptitle('Comparison of target and predicted mask', fontsize=16)
plt.show()

# %%
fig,axs=plt.subplots(1,2,figsize=(15,5))
axs[0].plot(train_accuracies_dice,color='red',label='dice')
axs[0].plot(train_accuracies_jaccard,color='blue',label='jaccard')
axs[0].plot(train_accuracies_pixel,color='green',label='pixel-wise')
axs[0].legend()
axs[0].set_title('Training accuracies')
axs[0].set_xlabel('Epoch number')
axs[0].set_ylabel('Accuracy)')

axs[1].plot(valid_accuracies_dice,color='red',label='dice')
axs[1].plot(valid_accuracies_jaccard,color='blue',label='jaccard')
axs[1].plot(valid_accuracies_pixel,color='green',label='pixel-wise')
axs[1].legend()
axs[1].set_title('Validation accuracies')
axs[1].set_xlabel('Epoch number')
axs[1].set_ylabel('Accuracy)')

fig,axs=plt.subplots(1,3,figsize=(15,5))
axs[0].plot(train_accuracies_dice,color='red',label='Training accuracy')
axs[0].plot(valid_accuracies_dice,color='blue',label='Validation accuracy')
axs[0].set_title('Dice coefficient accuracies')
axs[0].legend()

axs[1].plot(train_accuracies_jaccard,color='red',label='Training accuracy')
axs[1].plot(valid_accuracies_jaccard,color='blue',label='Validation accuracy')
axs[1].set_title('Jaccard coefficient accuracies')
axs[1].legend()

axs[2].plot(train_accuracies_pixel,color='red',label='Training accuracy')
axs[2].plot(valid_accuracies_pixel,color='blue',label='Validation accuracy')
axs[2].set_title('Pixelwise coefficient accuracies')
axs[2].legend()

# %%
from torchvision.utils import make_grid
inputs, targets = next(iter(test_loader))
inputs, targets = inputs.to(device), targets.to(device)

outputs = net(inputs)
_, predicted = torch.max(outputs.data, 1)

un_target=targets.unique()
# Compute loss.
targets[targets==un_target[0]]=0
targets[targets==un_target[1]]=1
targets[targets==un_target[2]]=2

targets = targets.to(torch.int64)

fig,axs = plt.subplots(1,3,figsize=(15,15))

axs[0].imshow(output.detach().cpu().numpy()[0,0,:,:])
axs[0].set_title('Label 1, probability')
axs[1].imshow(output.detach().cpu().numpy()[0,1,:,:])
axs[1].set_title('Label 2, probability')
axs[2].imshow(output.detach().cpu().numpy()[0,2,:,:])
axs[2].set_title('Label 3,probabiliy')
fig.suptitle('Probability distribution for each class', fontsize=16)
plt.show()

# %%
fig,axs=plt.subplots(2,2,figsize=(15,15))
im1=axs[1,0].imshow(predicted[0,:,:].cpu())
axs[1,0].set_title('Predicted labels')
plt.colorbar(im1, ax=axs[1, 0])
targets = targets.to(torch.int64) [0,:,:]
im2=axs[0,1].imshow(targets.cpu())
axs[0,1].set_title('Target labels')
plt.colorbar(im2, ax=axs[0,1])
im3=axs[0,0].imshow(inputs[0,0,:,:].cpu())
axs[0,0].set_title('Original image')
plt.colorbar(im3, ax=axs[0,0])
im4=axs[1,1].imshow(targets.cpu()-predicted[0,:,:].cpu())
axs[1,1].set_title('Difference between mask and prediction')
plt.colorbar(im4, ax=axs[1,1])

fig.suptitle('Comparison of target and predicted mask', fontsize=16)
plt.show()
